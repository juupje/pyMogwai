# %% [markdown]
# # PyMogwai Live Demo!
#
# ## Initialization
# First, we need to import the mogwai library

# %%
from mogwai.core.traversal import MogwaiGraphTraversalSource
from mogwai.core.steps.statics import *
from mogwai.parser import graphml_to_mogwaigraph

# %% [markdown]
# Then, load the graph!

# %%
airroutes_path = "tests/documents/air-routes-latest.graphml"
graph = graphml_to_mogwaigraph(airroutes_path, node_label_key="labelV", 
            edge_label_key="labelE", node_name_key="desc")

# %% [markdown]
# Finally, create a traversal source

# %%
g = MogwaiGraphTraversalSource(graph)

# %% [markdown]
# ## Let's go on a holiday!
# We want to go on holiday, where can we go from germany?

# %%
query = g.V().has_label("country").has_name("Germany")\
        .out("contains")\
        .out("route")\
        .in_("contains")\
        .has_label("country").name().dedup().to_list()
print("Query:",query.print_query())
res = query.run()
print("Result:", res[:10], "total: ", len(res))
# Out:
# Query: V -> Contains -> Has -> Out -> Out -> In -> Contains -> Values -> Dedup -> ToList
# Result: ['United States', 'Puerto Rico', 'Canada', 'United Kingdom', 'France', 'Finland', 'Japan', 'Singapore', 'United Arab Emirates', 'India'] total:  110

# %% [markdown]
# Okay, that's a bit much. Let's see what's the farthest we can get without a layover

# %%
query = g.V().has_label("country").has_name("Germany")\
        .out("contains")\
        .outE("route").as_("e")\
        .inV()\
        .in_("contains").has_label("country").as_('dest')\
        .select('e').properties('dist').max_()\
        .select('dest').by('name').next()
print("Result:", query.run())
# Out:
# Result: Argentina

# %% [markdown]
# Well, that's nice. Let's go there! But from which airport are we departing?

# %%
query = g.V().has_label("country").has_name("Germany")\
            .out("contains").as_('start')\
            .outE("route").as_("e")\
            .inV()\
            .in_("contains").has_label("country").as_('dest')\
            .select('e').properties('dist').as_('dist').max_().\
            select('start', 'dest', 'dist').to_list().by('name')
res = query.run()
print("Result:",res)
# Out:
# Result: [['Frankfurt am Main', 'Argentina', 7141]]

# %% [markdown]
# Hmm, that's a bit far away from Aachen. Let's see where we can go from a nearby airport

# %%
g.V().has_label("airport").within("city", ["Brussels", "Maastricht", "Aachen", "Dusseldorf"]).as_('start')\
            .outE("route").as_("e")\
            .inV()\
            .in_("contains").has_label("country").as_('dest')\
            .order(desc=True).by(select('e').properties('dist'))\
            .limit(5)\
            .select('start', 'dest').to_list().by('name').run()
# Out:
# [['Dusseldorf International Airport', 'Singapore'],
#  ['Brussels Airport', 'Japan'],
#  ['Brussels South Charleroi Airport', 'Hong Kong'],
#  ['Brussels Airport', 'Hong Kong'],
#  ['Brussels Airport', 'China']]

# %% [markdown]
# Those flights are really long...
# I guess we have to accept layovers then. Where can we go within three hops if we want to depart from Maastricht Aachen Airport? We don't want a flight longer than 2000 miles.

# %%
g.V().has_label('airport').has_property("city", "Maastricht").as_('start')\
    .repeat(
        outE('route').as_('e')\
        .inV().filter_(
            select('e').properties('dist').is_(lte(2000))
        ).simple_path()
    ).times(3).emit().as_('dest')\
    .path().as_('p')\
    .count(Scope.local).order(asc=True).as_('length')\
    .select('dest').dedup()\
    .select('dest', 'length').to_list().by('city').run()
# Out:
# [['Alicante', 3],
#  ['Alghero', 3],
#  ['Trapani', 3],
#  ['Girona', 3],
#  ['Catania', 3],
#  ['Kerkyra Island', 3],
#  ['Heraklion', 3],
#  ['Tenerife Island', 3],
#  ['Bari', 3],
#  ['Porto', 3],
#  ['Faro', 3],
#  ['Zakynthos', 3],
#  ['Antalya', 3],
#  ['Palma De Mallorca', 3],
#  ['Istanbul', 3],
#  ['Luqa', 3],
#  ['Kos Island', 3],
#  ['Geneva', 5],
#  ['Liverpool', 5],
#  ['Nottingham', 5],
#  ['London', 5],
#  ['Shannon', 5],
#  ['Manchester', 5],
#  ['Brussels', 5],
#  ['Zurich', 5],
#  ['Kalymnos Island', 5],
#  ['Barcelona', 5],
#  ['Rome', 5],
#  ['Dublin', 5],
#  ['Paris', 5],
#  ['London', 5],
#  ['London', 5],
#  ['Berlin', 5],
#  ['Paris', 5],
#  ['Madrid', 5],
#  ['Nice', 5],
#  ['Luxembourg', 5],
#  ['Lyon', 5],
#  ['Cork', 5],
#  ['Basle', 5],
#  ['Sevilla', 5],
#  ['Bristol', 5],
#  ['Leeds', 5],
#  ['Malaga', 5],
#  ['Milan', 5],
#  ['Gran Canaria', 5],
#  ['Lisbon', 5],
#  ['Doncaster', 5],
#  ['Nantes', 5],
#  ['Bologna', 5],
#  ['Pisa', 5],
#  ['Naples', 5],
#  ['Stuttgart', 5],
#  ['Bilbao', 5],
#  ['London', 5],
#  ['Rostock', 5],
#  ['Kaunas', 5],
#  ['Ostrava', 5],
#  ['Athens', 5],
#  ['Moscow', 5],
#  ['Glasgow', 5],
#  ['Edinburgh', 5],
#  ['Stockholm', 5],
#  ['Cologne', 5],
#  ['Hamburg', 5],
#  ['Vienna', 5],
#  ['Amsterdam', 5],
#  ['Frankfurt', 5],
#  ['Châlons/Vatry', 5],
#  ['Saint-Étienne/Bouthéon', 5],
#  ['Munich', 5],
#  ['Paderborn', 5],
#  ['Dusseldorf', 5],
#  ['Bergamo', 5],
#  ['Rygge', 5],
#  ['Leipzig', 5],
#  ['Nuremberg', 5],
#  ['Culleredo', 5],
#  ['Kraków', 5],
#  ['Erfurt', 5],
#  ['Birmingham', 5],
#  ['Rotterdam', 5],
#  ['Hannover', 5],
#  ['Rhodes', 5],
#  ['Riga', 5],
#  ['Salzburg', 5],
#  ['Cardiff', 5],
#  ['Belfast', 5],
#  ['Verona', 5],
#  ['Tel Aviv', 5],
#  ['Warsaw', 5],
#  ['Larnaca', 5],
#  ['Moscow', 5],
#  ['Kuwait', 5],
#  ['Bordeaux/Mérignac', 5],
#  ['Dresden', 5],
#  ['St. Petersburg', 5],
#  ['Toulouse/Blagnac', 5],
#  ['Kiev', 5],
#  ['Beirut', 5],
#  ['Marseille', 5],
#  ['Moscow', 5],
#  ['Tallinn', 5],
#  ['Newcastle', 5],
#  ['Granada', 5],
#  ['Memmingen', 5],
#  ['Hahn', 5],
#  ['Lille/Lesquin', 5],
#  ['Santander', 5],
#  ['Vigo', 5],
#  ['Ranón', 5],
#  ['Beauvais/Tillé', 5],
#  ['Bournemouth', 5],
#  ['Brussels', 5],
#  ['Grimsby', 5],
#  ['Lajes', 5],
#  ['Ponta Delgada', 5],
#  ['Valencia', 5],
#  ['Santiago de Compostela', 5],
#  ['Fuerteventura Island', 5],
#  ['Charleston', 5],
#  ['Sta Cruz de la Palma, La Palma Island', 5],
#  ['Blackpool', 5],
#  ['Baden-Baden', 5],
#  ['Glasgow', 5],
#  ['Prague', 5],
#  ['Vitoria', 5],
#  ['El Hierro Island', 5],
#  ['Zweibrücken', 5],
#  ['Saarbrücken', 5],
#  ['Zaragoza', 5],
#  ['Dole/Tavaux', 5],
#  ['Weeze', 5],
#  ['Billund', 5],
#  ['Belfast', 5],
#  ['Eindhoven', 5],
#  ['Aberdeen', 5],
#  ['Southampton', 5],
#  ['Bremen', 5],
#  ['Friedrichshafen', 5],
#  ['Münster', 5],
#  ['Warsaw', 5],
#  ['Killarney', 5],
#  ['Exeter', 5],
#  ['Southend', 5],
#  ['Dortmund', 5],
#  ['Newquay', 5],
#  ['Katowice', 5],
#  ['Bratislava', 5],
#  ['Kithira Island', 5],
#  ['Palermo', 5],
#  ['Souda', 5],
#  ['Copenhagen', 5],
#  ['Budapest', 5],
#  ['Oslo', 5],
#  ['Gothenburg', 5],
#  ['Clermont-Ferrand/Auvergne', 5],
#  ['Brest/Guipavas', 5],
#  ['Brive', 5],
#  ['Marrakech', 5],
#  ['Casablanca', 5],
#  ['Wroclaw', 5],
#  ['Funchal', 5],
#  ['Almería', 5],
#  ['Tours/Val de Loire (Loire Valley)', 5],
#  ['Carcassonne/Salvaza', 5],
#  ['La Rochelle/Île de Ré', 5],
#  ['Strasbourg', 5],
#  ['Cagliari', 5],
#  ['Roma', 5],
#  ['Montpellier/Méditerranée', 5],
#  ['Helsinki', 5],
#  ['Groningen', 5],
#  ['Ostend', 5],
#  ['Aarhus', 5],
#  ['Derry', 5],
#  ['London', 5],
#  ['Venice', 5],
#  ['Menorca', 5],
#  ['Thessaloniki', 5],
#  ['Ibiza', 5],
#  ['Rabat', 5],
#  ['Poznań', 5],
#  ['Bucharest', 5],
#  ['Milan', 5],
#  ['Turin', 5],
#  ['Visby', 5],
#  ['Pescara', 5],
#  ['Ancona', 5],
#  ['Lampedusa', 5],
#  ['Firenze', 5],
#  ['Vilnius', 5],
#  ['Lamezia Terme', 5],
#  ['Lviv', 5],
#  ['Brindisi', 5],
#  ['Venice', 5],
#  ['Cuneo', 5],
#  ['Parma', 5],
#  ['Trieste', 5],
#  ['Stockholm / Nyköping', 5],
#  ['Gothenburg', 5],
#  ['Torp', 5],
#  ['Perugia', 5],
#  ['Oradea', 5],
#  ['Lappeenranta', 5],
#  ['Kiev', 5],
#  ['Tampere / Pirkkala', 5],
#  ['Skellefteå', 5],
#  ['Genoa', 5],
#  ['Pantelleria', 5],
#  ['Preveza/Lefkada', 5],
#  ['Kefallinia Island', 5],
#  ['Voronezh', 5],
#  ['Krasnodar', 5],
#  ['Rennes/Saint-Jacques', 5],
#  ['Linz', 5],
#  ['Norwich', 5],
#  ['Nizhny Novgorod', 5],
#  ['Pardubice', 5],
#  ['Paros Island', 5],
#  ['Liège', 5],
#  ['Cluj-Napoca', 5],
#  ['Graz', 5],
#  ['Lublin', 5],
#  ['Tivat', 5],
#  ['Sofia', 5],
#  ['Tirana', 5],
#  ['Sharm el-Sheikh', 5],
#  ['Dubrovnik', 5],
#  ['Dubai', 5],
#  ['Debrecen', 5],
#  ['Benghazi', 5],
#  ['Zagreb', 5],
#  ['Doha', 5],
#  ['Comiso', 5],
#  ['Paphos', 5],
#  ['Istanbul', 5],
#  ['Tripoli', 5],
#  ['Tarbes/Lourdes/Pyrénées', 5],
#  ['Skopje', 5],
#  ['Belgrade', 5],
#  ['Minsk', 5],
#  ['Bodrum', 5],
#  ['Dalaman', 5],
#  ['İzmir', 5],
#  ['Ljubljana', 5],
#  ['Hurghada', 5],
#  ['Aalborg', 5],
#  ['Prishtina', 5],
#  ['Konya', 5],
#  ['Ad Dammam', 5],
#  ['Khartoum', 5],
#  ['Alexandria', 5],
#  ['Samara', 5],
#  ['Podgorica', 5],
#  ['Chişinău', 5],
#  ['Ankara', 5],
#  ['Kayseri', 5],
#  ['Varna', 5],
#  ['Sharjah', 5],
#  ['Tbilisi', 5],
#  ['Atyrau', 5],
#  ['Arbil', 5],
#  ['Jeddah', 5],
#  ['Tunis', 5],
#  ['Abu Dhabi', 5],
#  ['Manama', 5],
#  ['Cairo', 5],
#  ['Tehran', 5],
#  ['Riyadh', 5],
#  ['Baku', 5],
#  ['Ashgabat', 5],
#  ['Algiers', 5],
#  ['Amman', 5],
#  ['Annabah', 5],
#  ['Bergen', 5],
#  ['Stavanger', 5],
#  ['Trondheim', 5],
#  ['Växjö', 5],
#  ['Kjevik', 5],
#  ['Ålesund', 5],
#  ['Reykjavik', 5],
#  ['Tenerife', 5],
#  ['Karlstad', 5],
#  ['Umeå', 5],
#  ['Stockholm / Västerås', 5],
#  ['Årø', 5],
#  ['Karmøy', 5],
#  ['Tlemcen', 5],
#  ['Oran', 5],
#  ['Turku', 5],
#  ['Ivano-Frankivsk', 5],
#  ['Constantine', 5],
#  ['Yerevan', 5],
#  ['Kassel', 5],
#  ['Lübeck', 5],
#  ['Valladolid', 5],
#  ['Oulu / Oulunsalo', 5],
#  ['Lleida', 5],
#  ['Cuxhaven', 5],
#  ['Caen/Carpiquet', 5],
#  ['Nador', 5],
#  ['Jerez de la Forntera', 5],
#  ['Reus', 5],
#  ['Nicosia', 5],
#  ['Perm', 5],
#  ['Chelyabinsk', 5],
#  ['Bydgoszcz', 5],
#  ['Rostov-on-Don', 5],
#  ['Sulaymaniyah', 5],
#  ['Baghdad', 5],
#  ['Yekaterinburg', 5],
#  ['Goleniow', 5],
#  ['Adana', 5],
#  ['Makhachkala', 5],
#  ['Trabzon', 5],
#  ['Samsun', 5],
#  ['Łódź', 5],
#  ['Zhukovsky', 5],
#  ['Kazan', 5],
#  ['Grozny', 5],
#  ['Aqaba', 5],
#  ['Urmia', 5],
#  ['Kermanshah', 5],
#  ['Edremit', 5],
#  ['Isparta', 5],
#  ['Hatay', 5],
#  ['Şanlıurfa', 5],
#  ['Bingöl', 5],
#  ['Mardin', 5],
#  ['Agri', 5],
#  ['Kahramanmaraş', 5],
#  ['Muş', 5],
#  ['Batman', 5],
#  ['Van', 5],
#  ['Kars', 5],
#  ['Erzurum', 5],
#  ['Adıyaman', 5],
#  ['Erzincan', 5],
#  ['Iğdır', 5],
#  ['Ganja', 5],
#  ['Sirnak', 5],
#  ['Kherson', 5],
#  ['Nalchik', 5],
#  ['Mosul', 5],
#  ['Sinop', 5],
#  ['Kutahya', 5],
#  ['Aktau', 5],
#  ['Nizhnekamsk', 5],
#  ['Samarkand', 5],
#  ['Tyumen', 5],
#  ['Astrakhan', 5],
#  ['Sochi', 5],
#  ['Zaporizhia', 5],
#  ['Batumi', 5],
#  ['Nakhchivan', 5],
#  ['Hakkari', 5],
#  ['Diyarbakir', 5],
#  ['Çanakkale', 5],
#  ['Volgograd', 5],
#  ['Kharkiv', 5],
#  ['Najaf', 5],
#  ['Basrah', 5],
#  ['Tabriz', 5],
#  ['Mashhad', 5],
#  ['Isfahan', 5],
#  ['Yenbo', 5],
#  ['Ta’if', 5],
#  ['Medina', 5],
#  ['Buraidah', 5],
#  ['Shiraz', 5],
#  ['Elazığ', 5],
#  ['Sarajevo', 5],
#  ['Dnipropetrovsk', 5],
#  ['Nevşehir', 5],
#  ['Malatya', 5],
#  ['Sivas', 5],
#  ['Amasya', 5],
#  ['Kastamonu', 5],
#  ['Gaziantep', 5],
#  ['Constanţa', 5],
#  ['Košice', 5],
#  ['Misratah', 5],
#  ['Ufa', 5],
#  ['Donetsk', 5],
#  ['Gazipaşa', 5],
#  ['Odessa', 5],
#  ['Asmara', 5],
#  ['Ordu/Giresun', 5],
#  ['Denizli', 5],
#  ['Uşak', 5],
#  ['Bern', 5],
#  ['Ohrid', 5],
#  ['Innsbruck', 5],
#  ['Tripoli', 5],
#  ['Siirt', 5],
#  ['Lanzarote Island', 7],
#  ['Tangier', 7],
#  ['Sibiu', 7],
#  ['Nea Anchialos', 7],
#  ['Timişoara', 7],
#  ['Zadar', 7],
#  ['Pula', 7],
#  ['Burgas', 7],
#  ['Split', 7],
#  ['Agadir', 7],
#  ['Toulon/Hyères/Le Palyvestre', 7],
#  ['Oujda', 7],
#  ['Figari Sud-Corse', 7],
#  ['Biarritz/Anglet/Bayonne', 7],
#  ['Pau/Pyrénées (Uzein)', 7],
#  ['Monastir', 7],
#  ['Patras', 7],
#  ['Djerba', 7],
#  ['Kalamata', 7],
#  ['Ajaccio/Napoléon Bonaparte', 7],
#  ['Bastia/Poretta', 7],
#  ['Fes', 7],
#  ['Plovdiv', 7],
#  ['San Javier', 7],
#  ['Saint Peter Port', 7],
#  ['Saint Helier', 7],
#  ['Rzeszów', 7],
#  ['Castletown', 7],
#  ['Eilat', 7],
#  ['Nis', 7],
#  ['Kutaisi', 7],
#  ['Banja Luka', 7],
#  ['Calvi/Sainte-Catherine', 7],
#  ['Béziers/Vias', 7],
#  ['Gdańsk', 7],
#  ['Târgu Mureş', 7],
#  ['Iaşi', 7],
#  ['Crotone', 7],
#  ['Chernivtsi', 7],
#  ['Craiova', 7],
#  ['Arad', 7],
#  ['Mostar', 7],
#  ['Brno', 7],
#  ['Karpathos Island', 7],
#  ['Olbia', 7],
#  ['Reggio Calabria', 7],
#  ['Valladolises', 7],
#  ['Vila Baleira', 7],
#  ['Kittila', 7],
#  ['Östersund', 7],
#  ['Rovaniemi', 7],
#  ['Ivalo', 7],
#  ['Limoges/Bellegarde', 7],
#  ['Klagenfurt am Wörthersee', 7],
#  ['Grenoble', 7],
#  ['Biskra', 7],
#  ['Perpignan/Rivesaltes', 7],
#  ['Batna', 7],
#  ['Sfax', 7],
#  ['Tuzla', 7],
#  ['Gibraltar', 7],
#  ['Tromsø', 7],
#  ['Enfidha', 7],
#  ['Hassi Messaoud', 7],
#  ['Inverness', 7],
#  ['Rijeka', 7],
#  ['Santorini Island', 7],
#  ['Mykonos Island', 7],
#  ['Antwerp', 7],
#  ['Bergerac/Roumanière', 7],
#  ['Kuusamo', 7],
#  ['Waterford', 7],
#  ['Mytilene', 7],
#  ['Melilla', 7],
#  ['Béjaïa', 7],
#  ['Poitiers/Biard', 7],
#  ['Metz / Nancy', 7],
#  ['Sétif', 7],
#  ['Le Havre/Octeville', 7],
#  ['Lorient/Lann/Bihoué', 7],
#  ['Angelsey', 7],
#  ['Ouarzazate', 7],
#  ['Essaouira', 7],
#  ['Praia', 7],
#  ['Velas', 7],
#  ['Santa Cruz das Flores', 7],
#  ['Pico Island', 7],
#  ['Horta', 7],
#  ['Vila do Porto', 7],
#  ['Rodez/Marcillac', 7],
#  ['Nîmes/Garons', 7],
#  ['Stockholm', 7],
#  ['Eskişehir', 7],
#  ['Brač Island', 7],
#  ['Lugano', 7],
#  ['Marina  Di Campo', 7],
#  ['Westerland', 7],
#  ['Heringsdorf', 7],
#  ['Samos Island', 7],
#  ['Chambéry/Aix-les-Bains', 7],
#  ['Lerwick', 7],
#  ['Stornoway', 7],
#  ['Orkney Islands', 7],
#  ['Osijek', 7],
#  ['Kavala', 7],
#  ['Rimini', 7],
#  ['Crete Island', 7],
#  ['Norrköping', 7],
#  ['Maribor', 7],
#  ['Chios Island', 7],
#  ['Linköping', 7],
#  ['Durham', 7],
#  ['Dundee', 7],
#  ['Uralsk', 7],
#  ['Jönköping', 7],
#  ['Pamplona', 7],
#  ['Altenrhein', 7],
#  ['Marsa Alam', 7],
#  ['Malmö', 7],
#  ['Kraljevo', 7],
#  ['Kaliningrad', 7],
#  ['Saratov', 7],
#  ['Hondarribia', 7],
#  ['Logroño', 7],
#  ['Badajoz', 7],
#  ['Dakar', 7],
#  ['Dinard/Pleurtuit/Saint-Malo', 7],
#  ['Dakhla', 7],
#  ['Quimper/Pluguffan', 7],
#  ['Lannion', 7],
#  ['Le Puy/Loudes', 7],
#  ['Castres/Mazamet', 7],
#  ['Périgueux/Bassillac', 7],
#  ['Agen/La Garenne', 7],
#  ['Tozeur', 7],
#  ['Aurillac', 7],
#  ['Szcytno', 7],
#  ['Bolzano', 7],
#  ['Bacău', 7],
#  ['Donegal', 7],
#  ['Burgos', 7],
#  ['León', 7],
#  ['Salamanca', 7],
#  ['Satu Mare', 7],
#  ['Goulimime', 7],
#  ['Nouadhibou', 7],
#  ['El Aaiún', 7],
#  ['Banjul', 7],
#  ['Nouakchott', 7],
#  ['Bissau', 7],
#  ['Senou', 7],
#  ['São Pedro', 7],
#  ['Rabil', 7],
#  ['Espargos', 7],
#  ['Hawarden', 7],
#  ['Skiathos', 7],
#  ['Tetuan', 7],
#  ['Dabaa', 7],
#  ['Châteauroux/Déols', 7],
#  ['Luxor', 7],
#  ['Suceava', 7],
#  ['Barnaul', 7],
#  ['Castellón de La Plana', 7],
#  ["St. Mary's", 7],
#  ['Astana', 7],
#  ['Eilat', 7],
#  ['Mannheim', 7],
#  ['Sleptsovskaya', 7],
#  ['Bryansk', 7],
#  ['Ulyanovsk', 7],
#  ['Naryan Mar', 7],
#  ['Saransk', 7],
#  ['Orenburg', 7],
#  ['Cheboksary', 7],
#  ['Bugulma', 7],
#  ['Syktyvkar', 7],
#  ['Ukhta', 7],
#  ['Kursk', 7],
#  ['Belgorod', 7],
#  ['Yaroslavl', 7],
#  ['Novy Urengoy', 7],
#  ['Kirov', 7],
#  ['Izhevsk', 7],
#  ['Cherepovets', 7],
#  ['Mineralnyye Vody', 7],
#  ['Urgench', 7],
#  ['Novosibirsk', 7],
#  ['Beslan', 7],
#  ['Gelendzhik', 7],
#  ['Anapa', 7],
#  ['Norilsk', 7],
#  ['Omsk', 7],
#  ['Murmansk', 7],
#  ['Archangelsk', 7],
#  ['Simferopol', 7],
#  ['Gyumri', 7],
#  ['Lankaran', 7],
#  ['Karaganda', 7],
#  ['Karlovy Vary', 7],
#  ['Palanga', 7],
#  ['Vinnitsa', 7],
#  ['Sevastopol', 7],
#  ['Tashkent', 7],
#  ['Dijon/Longvic', 7],
#  ['Hamburg', 7],
#  ['Skiros Island', 7],
#  ['Limnos Island', 7],
#  ['Kuopio / Siilinjärvi', 7],
#  ['Kokkola / Kruunupyy', 7],
#  ['Kajaani', 7],
#  ['Kemi / Tornio', 7],
#  ['Jyväskylän Maalaiskunta', 7],
#  ['Joensuu / Liperi', 7],
#  ['Tartu', 7],
#  ['Mariehamn', 7],
#  ['Pori', 7],
#  ['Vaasa', 7],
#  ['Savonlinna', 7],
#  ['Enontekio', 7],
#  ['Syros Island', 7],
#  ['Astypalaia Island', 7],
#  ['Naxos Island', 7],
#  ['Milos Island', 7],
#  ['Leros Island', 7],
#  ['Kozani', 7],
#  ['Kastoria', 7],
#  ['Ioannina', 7],
#  ['Ikaria Island', 7],
#  ['Alexandroupolis', 7],
#  ['Tel Aviv', 7],
#  ['Eilat', 7],
#  ['Addis Ababa', 7],
#  ['Damascus', 7],
#  ['Al Ain', 7],
#  ['Sohag', 7],
#  ['Assiut', 7],
#  ['Jebel Ali', 7],
#  ['Lahore', 7],
#  ['Islamabad', 7],
#  ['Muscat', 7],
#  ['Mumbai', 7],
#  ['New Delhi', 7],
#  ['Vasco da Gama', 7],
#  ['Bishkek', 7],
#  ['Riyan', 7],
#  ['Sialkot', 7],
#  ['Peshawar', 7],
#  ['Lamerd', 7],
#  ['Lar', 7],
#  ['Kabul', 7],
#  ["Sana'a", 7],
#  ['Ahmedabad', 7],
#  ['Ahwaz', 7],
#  ['Wick', 7],
#  ['Port Ellen', 7],
#  ['Campbeltown', 7],
#  ['Osh', 7],
#  ['Kzyl-Orda', 7],
#  ['Surgut', 7],
#  ['Nizhnevartovsk', 7],
#  ['Khanty-Mansiysk', 7],
#  ['Salekhard', 7],
#  ['Magnitogorsk', 7],
#  ['Stavropol', 7],
#  ['Kostanay', 7],
#  ['Novokuznetsk', 7],
#  ['Tomsk', 7],
#  ['Kemerovo', 7],
#  ['Almaty', 7],
#  ['Bukhara', 7],
#  ['Ulyanovsk', 7],
#  ['Dushanbe', 7],
#  ['Balemartine', 7],
#  ['Eoligarry', 7],
#  ['Balivanich', 7],
#  ['Vorkuta', 7],
#  ['Termez', 7],
#  ['Khanabad', 7],
#  ['Navoi', 7],
#  ['Nukus', 7],
#  ['Fergana', 7],
#  ['Andizhan', 7],
#  ['Kurgan-Tyube', 7],
#  ['Khudzhand', 7],
#  ['Kulyab', 7],
#  ['Kurgan', 7],
#  ['Noyabrsk', 7],
#  ['Namangan', 7],
#  ['Gomel', 7],
#  ['Lipetsk', 7],
#  ['Penza', 7],
#  ['Orsk', 7],
#  ['Nadym', 7],
#  ['Gabala', 7],
#  ['Aktyuinsk', 7],
#  ['Pavlodar', 7],
#  ['Ust Kamenogorsk', 7],
#  ['Taraz', 7],
#  ['Kokshetau', 7],
#  ['Shymkent', 7],
#  ['Beloyarskiy', 7],
#  ['Elista', 7],
#  ['Taganrog', 7],
#  ['Gorno-Altaysk', 7],
#  ['Petrozavodsk', 7],
#  ['Apatity', 7],
#  ['Pajala', 7],
#  ['Torsby', 7],
#  ['Kuressaare', 7],
#  ['Karup', 7],
#  ['Kastelorizo Island', 7],
#  ['Sovetskiy', 7],
#  ['Chlef', 7],
#  ['Augsburg', 7],
#  ['Kaluga', 7],
#  ['Tambov', 7],
#  ['Zonguldak', 7],
#  ['Deauville', 7],
#  ['Vagar', 7],
#  ['Sønderborg', 7],
#  ['Rønne', 7],
#  ['Sundsvall/ Härnösand', 7],
#  ['Arvidsjaur', 7],
#  ['Ängelholm', 7],
#  ['Luleå', 7],
#  ['Hagfors', 7],
#  ['Ronneby', 7],
#  ['Vilhelmina', 7],
#  ['Kiruna', 7],
#  ['Örnsköldsvik', 7],
#  ['Lycksele', 7],
#  ['Kramfors / Sollefteå', 7],
#  ['Gällivare', 7],
#  ['Sveg', 7],
#  ['Halmstad', 7],
#  ['Kalmar', 7],
#  ['Kristianstad', 7],
#  ['Mora', 7],
#  ['Freetown', 7],
#  ['Ouagadougou', 7],
#  ['Bouarfa', 7],
#  ['Al Hoceima', 7],
#  ['Zouérate', 7],
#  ['Conakry', 7],
#  ['Monrovia', 7],
#  ['Niamey', 7],
#  ['Abidjan', 7],
#  ['Santa Cruz da Graciosa', 7],
#  ['Esbjerg', 7],
#  ['Baia Mare', 7],
#  ['Uzhhorod', 7],
#  ['Kvernberget', 7],
#  ['Kufra', 7],
#  ['Hyderabad', 7],
#  ['Jaipur', 7],
#  ['Karachi', 7],
#  ['Calicut', 7],
#  ['Kathmandu', 7],
#  ['Bengaluru', 7],
#  ['Chennai', 7],
#  ['Malé', 7],
#  ['Madurai', 7],
#  ['Faisalabad', 7],
#  ['Mogadishu', 7],
#  ['Chandigarh', 7],
#  ['Amritsar', 7],
#  ['Sir Bani Yas Island', 7],
#  ['Lucknow', 7],
#  ['Al Ahsa', 7],
#  ['Abha', 7],
#  ['Kandahar', 7],
#  ['Gheshm', 7],
#  ['Djibouti City', 7],
#  ['Berbera', 7],
#  ["Ha'il", 7],
#  ['Tiruchirappally', 7],
#  ['Trivandrum', 7],
#  ['Cochin', 7],
#  ['Aden', 7],
#  ['Pune', 7],
#  ['Mangalore', 7],
#  ['Multan', 7],
#  ['Salalah', 7],
#  ['Abu Dhabi', 7],
#  ['Zahedan', 7],
#  ['Tabuk', 7],
#  ['Bandar Abbas', 7],
#  ['Bandar Lengeh', 7],
#  ['Kish Island', 7],
#  ['Bushehr', 7],
#  ['Hodeida', 7],
#  ['Tamanrasset', 7],
#  ['Guemar', 7],
#  ['Ouargla', 7],
#  ['Touggourt', 7],
#  ['In Salah', 7],
#  ['Ghardaïa', 7],
#  ['Adrar', 7],
#  ['El Bayadh', 7],
#  ['Mascara', 7],
#  ['Tiaret', 7],
#  ["Hassi R'Mel", 7],
#  ['Tébessi', 7],
#  ['Mecheria', 7],
#  ['Djanet', 7],
#  ['Al Bayda', 7],
#  ['Tobruk', 7],
#  ['Sirt', 7],
#  ['Gabès', 7],
#  ['Ghadames', 7],
#  ['Ghat', 7],
#  ['Ubari', 7],
#  ['Ürümqi', 7],
#  ['Al Ula', 7],
#  ["Ta'izz", 7],
#  ['Wadi al-Dawasir', 7],
#  ['Turaif', 7],
#  ['Al-Jawf', 7],
#  ['Sharurah', 7],
#  ['Arar', 7],
#  ['Rafha', 7],
#  ['Qaisumah', 7],
#  ['Guriat', 7],
#  ['Jizan', 7],
#  ['Dawadmi', 7],
#  ['Bisha', 7],
#  ['Al Baha', 7],
#  ['Nejran', 7],
#  ['Port Sudan', 7],
#  ['Aswan', 7],
#  ['Al Wajh', 7],
#  ['Nairobi', 7],
#  ['Sayun', 7],
#  ['Ras Al Khaimah', 7],
#  ['Mazar-i-Sharif Airport', 7],
#  ['Herat', 7],
#  ['Kannur', 7],
#  ['Sohar', 7],
#  ['Naqpur', 7],
#  ['Mirpur Khas', 7],
#  ['Leirvik', 7],
#  ['Sogndal', 7],
#  ['Sandane', 7],
#  ['Longyearbyen', 7],
#  ['Røros', 7],
#  ['Ørsta', 7],
#  ['Ørland', 7],
#  ['Kirkenes', 7],
#  ['Alstahaug', 7],
#  ['Leirin', 7],
#  ['Evenes', 7],
#  ['Målselv', 7],
#  ['Bodø', 7],
#  ['Brønnøy', 7],
#  ['Førde', 7],
#  ['Alta', 7],
#  ['Florø', 7],
#  ['Svolvær', 7],
#  ['Leknes', 7],
#  ['Hadsel', 7],
#  ['Borlange', 7],
#  ['Rahim Yar Khan', 7],
#  ['Juba', 7],
#  ['Kano', 7],
#  ['Akureyri', 7],
#  ['Nuuk', 7],
#  ['Saint Anne', 7],
#  ['Avignon/Caumont', 7],
#  ['Alajero, La Gomera Island', 7],
#  ['Rørvik', 7],
#  ['Mo i Rana', 7],
#  ['Namsos', 7],
#  ['Mosjøen', 7],
#  ['Geiteryggen', 7],
#  ['Béchar', 7],
#  ['Kerman', 7],
#  ['Krasnoyarsk', 7],
#  ['Kogalym', 7],
#  ['Uray', 7],
#  ['Nyagan', 7],
#  ['Çorlu', 7],
#  ['Kosekoy', 7],
#  ['Tehran', 7],
#  ['Zabol', 7],
#  ['Yazd', 7],
#  ['Ardabil', 7],
#  ['Sari', 7],
#  ['Ramsar', 7],
#  ['Now Shahr', 7],
#  ['Gorgan', 7],
#  ['Birjand', 7],
#  ['Hamadan', 7],
#  ['Quetta', 7],
#  ['Rasht', 7],
#  ['Abadan', 7],
#  ['Chabahar', 7],
#  ['Asalouyeh', 7],
#  ['Sirri Island', 7],
#  ['Turbat', 7],
#  ['Dera Ghazi Khan', 7],
#  ['Coimbatore', 7],
#  ['Varanasi', 7],
#  ['Magdalla', 7],
#  ['Bandar Mahshahr', 7],
#  ['Nyala', 7],
#  ['Geneina', 7],
#  ['El Fasher', 7],
#  ["N'Djamena", 7],
#  ['Grosetto', 7]]
