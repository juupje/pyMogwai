# %% [markdown]
# First, we download the webpage of the Practical Gremlin book

# %%
from bs4 import BeautifulSoup
import requests
import re
response = requests.get("https://kelvinlawrence.net/book/Gremlin-Graph-Guide.html")

# %% [markdown]
# Then we extract all Gremlin queries on this page

# %%
pattern = re.compile(r"g\.(?:V|E|add).*(?:\;|$)")
newpattern = re.compile(r"g\.(?:V|E|add)(?:[^\)]+\)+\.[a-zA-Z])*[^\)]+\)+")

# %%
# Assuming the response from the GET request is stored in the variable 'response'
soup = BeautifulSoup(response.text, 'html.parser')

#find all sections
sections = soup.find_all('div', {"class": "sect1"})
section_filter = filter(lambda x: x.find('h2').get_text().split(".")[0] in ["3", "4", "5"], sections)

queries = []

for section in section_filter:
	# Find all code blocks in the HTML page
	code_blocks = section.find_all('code')

	# Extract the text from each code block
	code_texts = (line for code in code_blocks for line in code.get_text(strip=True).split("\n") if len(line)>0)

	# Print the extracted code texts
	for code_text in code_texts:
		# Find all occurrences of the pattern in the code text
		queries.extend(newpattern.findall(code_text))

# %%
len(queries)
# Out:
# 908

# %%
for i, query in enumerate(queries):
	print(f"{i+1}: {query}")

# %% [markdown]
# Now, we'd like to find all steps used in these queries

# %%
steps = {}
steps_pattern = re.compile(r"(\w+)\(")
for query in queries:
	for step in steps_pattern.findall(query):
		steps[step] = steps.get(step, 0) + 1

# %%
print(len(steps))
print(steps)
# Out:
# 131
# {'V': 885, 'hasLabel': 239, 'groupCount': 43, 'by': 577, 'has': 703, 'out': 383, 'path': 135, 'repeat': 68, 'times': 32, 'next': 72, 'getClass': 3, 'values': 244, 'E': 28, 'hasNot': 1, 'not': 21, 'count': 209, 'outE': 88, 'label': 20, 'group': 79, 'select': 161, 'fold': 83, 'in': 22, 'inV': 58, 'limit': 151, 'as': 207, 'from': 28, 'to': 34, 'dedup': 32, 'hasNext': 2, 'project': 30, 'unfold': 66, 'inE': 5, 'outV': 7, 'tail': 7, 'range': 7, 'timeLimit': 2, 'until': 30, 'skip': 2, 'both': 13, 'valueMap': 76, 'with': 9, 'elementMap': 3, 'union': 30, 'id': 19, 'toList': 19, 'join': 3, 'toSet': 1, 'order': 80, 'toBulkSet': 2, 'fill': 4, 'hasId': 32, 'between': 18, 'lt': 18, 'where': 72, 'is': 71, 'eq': 15, 'neq': 32, 'mean': 12, 'local': 27, 'sum': 12, 'max': 8, 'min': 2, 'gte': 8, 'inside': 3, 'outside': 2, 'within': 33, 'without': 14, 'gt': 55, 'lte': 8, 'and': 13, 'coin': 4, 'sample': 12, 'startingWith': 5, 'or': 10, 'endingWith': 1, 'containing': 2, 'notStartingWith': 1, 'notEndingWith': 1, 'notContaining': 6, 'filter': 22, 'choose': 14, 'option': 8, 'constant': 22, 'match': 5, 'identity': 9, 'sideEffect': 2, 'store': 8, 'aggregate': 10, 'inject': 1, 'coalesce': 13, 'optional': 2, 'bothE': 15, 'bothV': 5, 'otherV': 5, 'simplePath': 31, 'loops': 7, 'emit': 12, 'cap': 13, 'cyclicPath': 5, 'addE': 31, 'math': 14, 'signum': 1, 'withIndex': 2, 'indexed': 1, 'index': 7, 'addV': 41, 'property': 79, 'size': 1, 'drop': 14, 'properties': 51, 'value': 10, 'key': 9, 'propertyMap': 1, 'hasValue': 7, 'element': 2, 'graph': 1, 'explain': 2, 'keys': 3, 'sack': 36, 'get': 12, 'startsWith': 1, 'toString': 1, 'contains': 2, 'map': 8, 'flatMap': 3, 'test': 2, 'regex': 1, 'tree': 2, 'subgraph': 7, 'profile': 2, 'sort': 1}

# %%
#steps in PyMogwai
steps_in_pymogwai = {"filter", "has", "hasId", "hasName", "hasLabel", "is",
                     "contains", "within", "simplePath", "limit", "dedup", "identity", "name",
                     "value", "label", "properties", "select", "order", "count", "path",
                     "max", "min", "sum", "mean", "out", "outE", "outV", "inE", "inV",
                     "in", "both", "bothE", "bothV", "repeat", "branch", "option", "until",
                     "times", "emit", "as", "by", "sideEffect", "property", "toList", "next",
                     "iter","asPath", "V", "E", "gt", "gte", "lt", "lte", "or", "not", "and"}
len(steps_in_pymogwai)
# Out:
# 57

# %%
query_step_map = {query: steps_pattern.findall(query) for query in queries}
counter = 0
for query, steps in query_step_map.items():
	if len(set(steps)-steps_in_pymogwai)>0:
		counter += 1
		print(f"{query}: {set(steps)-steps_in_pymogwai}")
print(f"{counter} queries contain steps not in PyMogwai")
# Out:
# g.V().hasLabel('airport').groupCount().by('country'): {'groupCount'}
# g.V().has('airport','code','DFW').next().getClass(): {'getClass'}
# g.V().has('airport','code','DFW').values(): {'values'}
# g.V().has('airport','code','DFW').values('city'): {'values'}
# g.V().has('airport','code','DFW').values('runways','icao'): {'values'}
# g.V().hasNot('region'): {'hasNot'}
# g.V().groupCount().by(label): {'groupCount'}
# g.V().label().groupCount(): {'groupCount'}
# g.E().groupCount().by(label): {'groupCount'}
# g.E().label().groupCount(): {'groupCount'}
# g.V().group().by(label).by(count()): {'group'}
# g.V().hasLabel('country').group().by('code').by(out().count()): {'group'}
# g.V().hasLabel('continent').group().by('code').by(out().count()): {'group'}
# g.V().hasLabel('airport').groupCount().by('country').select('FR'): {'groupCount'}
# g.V().hasLabel('airport').groupCount().by('country').select('FR','GR','BE'): {'groupCount'}
# g.V().has('airport','code','AUS').out().values('code').fold(): {'values', 'fold'}
# g.V().has('airport','code','AUS').out('route').values('code').fold(): {'values', 'fold'}
# g.V().has('airport','code','AUS').out('route').out('route').values('code'): {'values'}
# g.V().has('airport','code','LCY').in('route').values('code'): {'values'}
# g.V().has('code','LHR').out('route').has('country','US').values('code'): {'values'}
# g.V().has('airport','code','LCY').out().limit(5).values('runways').path().by('code').by('code').by(): {'values'}
# g.V(3).out().limit(5).path().by(values('code','city').fold()): {'values', 'fold'}
# g.V().has('airport','code','AUS').out().as('a').out().as('b').path().by('code').from('a').to('b').limit(10): {'from', 'to'}
# g.V().has('airport','code','AUS').out().as('a').out().path().by('code').from('a').limit(10): {'from'}
# g.V().has('airport','code','AUS').out().as('a').out().as('b').out().path().by('code').from('a').to('b').limit(10): {'from', 'to'}
# g.V().has('airport','code','AUS').out().out().as('b').out().path().by('code').to('b').limit(10): {'to'}
# g.V().has('airport','code','AUS').as('a').out().out().as('b').out().path().by('code').to('b').limit(10).dedup(): {'to'}
# g.V().has('code','AUS').out('route').has('code','DFW').hasNext(): {'hasNext'}
# g.V().has('code','AUS').out('route').has('code','SYD').hasNext(): {'hasNext'}
# g.V().has('type','airport').limit(10).project('a','b','c').by('code').by('region').by(out().count()): {'project'}
# g.V().has('type','airport').limit(10).project('IATA','Region','Routes').by('code').by('region').by(out().count()): {'project'}
# g.V().has('code','AUS').as('a').out().as('a').limit(10).select(last,'a').by('code').fold(): {'fold'}
# g.V().has('code','AUS').as('a').out().as('a').limit(10).select(first,'a').by('code').fold(): {'fold'}
# g.V().has('code','AUS').as('a').out().as('a').limit(10).select(all,'a').unfold().values('code').fold(): {'unfold', 'values', 'fold'}
# g.V().has('code','LAX').out().as('stop').out().out().as('stop').out().out().as('stop').limit(1).select(all,'stop').unfold().values('code').fold(): {'unfold', 'values', 'fold'}
# g.V().has('code','MIA').outE().as('e').inV().has('code','DFW').select('e').values('dist'): {'values'}
# g.V().has('code','MIA').inE().as('e').outV().has('code','DFW').select('e').values('dist'): {'values'}
# g.V().hasLabel('airport').values('code').limit(20): {'values'}
# g.V().hasLabel('airport').values('code').tail(20): {'values', 'tail'}
# g.V().hasLabel('airport').limit(20).values('code'): {'values'}
# g.V().hasLabel('airport').range(0,20).values('code'): {'values', 'range'}
# g.V().has('airport','code','AUS').repeat(timeLimit(10).out()).until(has('code','LHR')).path().by('code'): {'timeLimit'}
# g.V().has('airport','code','AUS').repeat(timeLimit(20).out()).until(has('code','LHR')).path().by('code'): {'timeLimit'}
# g.V().hasLabel('airport').range(0,2): {'range'}
# g.V().hasLabel('airport').range(3,6): {'range'}
# g.V().range(3500,-1): {'range'}
# g.V().hasLabel('country').range(0,2): {'range'}
# g.V().has('region','US-TX').skip(5).fold(): {'skip', 'fold'}
# g.V().has('region','US-TX').range(5,-1).fold(): {'fold', 'range'}
# g.V().has('region','US-TX').fold(): {'fold'}
# g.V().has('region','US-TX').fold().skip(local,3): {'skip', 'fold'}
# g.V().has('region','GB-ENG').values('runways').fold(): {'values', 'fold'}
# g.V().has('region','GB-ENG').values('runways').dedup().fold(): {'values', 'fold'}
# g.V().has('region','GB-ENG').dedup().by('runways').values('code','runways').fold(): {'values', 'fold'}
# g.V().has('code','AUS').valueMap().unfold(): {'unfold', 'valueMap'}
# g.V().has('code','AUS').valueMap(true).unfold(): {'unfold', 'valueMap'}
# g.V().has('code','AUS').valueMap(true,'region'): {'valueMap'}
# g.V().has('code','AUS').valueMap().select('code','icao','desc'): {'valueMap'}
# g.V().has('code','AUS').valueMap(true,'code','icao','desc','city').unfold(): {'unfold', 'valueMap'}
# g.E(5161).valueMap(true): {'valueMap'}
# g.V().has('code','SFO').valueMap().with(WithOptions.tokens).unfold(): {'unfold', 'with', 'valueMap'}
# g.V().has('code','SFO').valueMap('code').with(WithOptions.tokens).unfold(): {'unfold', 'with', 'valueMap'}
# g.V().has('code','SFO').valueMap('code').with(WithOptions.tokens,WithOptions.labels).unfold(): {'unfold', 'with', 'valueMap'}
# g.V().has('code','SFO').valueMap('code').with(WithOptions.tokens,WithOptions.ids).unfold(): {'unfold', 'with', 'valueMap'}
# g.V().has('code','SFO').valueMap().by(unfold()).unfold(): {'unfold', 'valueMap'}
# g.V().has('code','AUS').elementMap().unfold(): {'unfold', 'elementMap'}
# g.V().has('code','AUS').elementMap('city'): {'elementMap'}
# g.V(3).outE().limit(1).elementMap(): {'elementMap'}
# g.E(5161).project('v','IN','OUT').by(valueMap(true)).by(inV().union(id(): {'project', 'id', 'valueMap', 'union'}
# g.E(5161).project('v','IN','OUT').by(valueMap(true)).by(project('id','label').by(inV().id()).by(inV().label())).by(project('id','label').by(outV().id()).by(outV().label())).unfold(): {'project', 'unfold', 'id', 'valueMap'}
# g.V().has('code','AUS').valueMap().next(): {'valueMap'}
# g.V().has('airport','region','US-TX').values('runways').toList().join(','): {'join', 'values'}
# g.V().has('airport','region','US-TX').values('runways').toSet().join(','): {'toSet', 'join', 'values'}
# g.V().has('airport','region','US-TX').values('runways').dedup().order().fold(): {'values', 'fold'}
# g.V().has('airport','region','US-TX').values('runways').toList(): {'values'}
# g.V().has('airport','region','US-TX').values('runways').toBulkSet().join(','): {'toBulkSet', 'join', 'values'}
# g.V().has('airport','region','US-TX').values('runways').toBulkSet(): {'toBulkSet', 'values'}
# g.V().has('airport','region','US-TX').values('runways').fill(a): {'fill', 'values'}
# g.V().has('airport','region','US-TX').values('runways').fill(s): {'fill', 'values'}
# g.V().has('code','DFW').id(): {'id'}
# g.V().hasId(8).values('code'): {'values'}
# g.V().has(id,8).values('code'): {'values'}
# g.V().hasId(between(1,6)): {'between'}
# g.V().has(id,between(1,6)): {'between'}
# g.V(3).values('code'): {'values'}
# g.V(3,6,8,15).values('code'): {'values'}
# g.V(a).values('code'): {'values'}
# g.V().hasLabel('country').has('code','AU').out('contains').values('code'): {'values'}
# g.V().has('country','code','AU').out().values('code'): {'values'}
# g.V().where(label().is(eq('airport'))).count(): {'eq', 'where'}
# g.V().has(label,neq('airport')).count(): {'neq'}
# g.V().where(label().is(neq('airport'))).count(): {'neq', 'where'}
# g.E().where(label().is(eq('route'))).count(): {'eq', 'where'}
# g.V().hasLabel('airport').local(out('route').count()).mean(): {'local'}
# g.V().hasLabel('airport').local(out('route').count()).limit(10): {'local'}
# g.V().has('region','GB-SCT').order().by('code').values('code','city').fold(): {'values', 'fold'}
# g.V().has('region','GB-SCT').order().by('code').local(values('code','city').fold()): {'values', 'fold', 'local'}
# g.V().hasLabel('airport').values('runways').sum(): {'values'}
# g.V().hasLabel('airport').values('runways').mean(): {'values'}
# g.V().hasLabel('airport').values('longest').mean(): {'values'}
# g.V().hasLabel('airport').local(both('route').count()).mean(): {'local'}
# g.V().hasLabel('airport').values('longest').max(): {'values'}
# g.V().hasLabel('airport').local(out('route').count()).max(): {'local'}
# g.V().hasLabel('airport').values('longest').min(): {'values'}
# g.V().hasLabel('continent').values('desc').min(): {'values'}
# g.V().hasLabel('continent').values('desc').max(): {'values'}
# g.V().hasLabel('continent').values('desc').order().limit(1): {'values'}
# g.V().hasLabel('continent').values('desc').order().by(desc).limit(1): {'values'}
# g.V().has('runways',gte(5)).values('code','runways').fold(): {'values', 'fold'}
# g.V().has('runways',lt(3)).values('code','runways').fold(): {'values', 'fold'}
# g.V().has('runways',eq(3)).count(): {'eq'}
# g.V().has('runways',neq(1)).count(): {'neq'}
# g.V().values('runways').is(3).count(): {'values'}
# g.V().has('runways',inside(3,6)).values('code','runways'): {'values', 'inside'}
# g.V().has('runways',outside(3,6)).values('code','runways'): {'values', 'outside'}
# g.V().has('runways',within(3..6)).values('code','runways').limit(15): {'values'}
# g.V().has('runways',within(1,2,3)).values('code','runways').limit(15): {'values'}
# g.V().has('runways',without(3..6)).values('code','runways').limit(15): {'values', 'without'}
# g.V().has('runways',between(5,8)).values('code','runways').fold(): {'between', 'values', 'fold'}
# g.V().hasId(between(1,47)).out().hasId(lte(46)).count(): {'between'}
# g.V().hasId(within(1..46)).out().hasId(between(1,47)).count(): {'between'}
# g.V().hasId(inside(0,47)).out().hasId(lte(46)).count(): {'inside'}
# g.V().has('airport','region','US-TX').has('city',neq('Houston')).values('code'): {'neq', 'values'}
# g.V().has('airport','code','AUS').out().has('code',without('PHX','LAX')).out().has('code','LAS').path().by('code'): {'without'}
# g.V().has('airport','code','AUS').out().has('country',within('US','CA')).has('code',without('PHX','LAX')).out().has('code','LAS').path().by('code'): {'without'}
# g.V().hasLabel('airport').has('city',between('Dal','Dam')).values('city'): {'between', 'values'}
# g.V().hasLabel('airport').has('city',between('Dal','Dam')).values('city').dedup(): {'between', 'values'}
# g.V().hasLabel('airport').has('city',between('Dal','Dat')).values('city').order().dedup(): {'between', 'values'}
# g.V().has('airport','code',between('X','Xa')).values('code').fold(): {'between', 'values', 'fold'}
# g.V().has('airport','code','AUS').out().has('code',neq('DFW')).out().has('code','SYD').path().by('code'): {'neq'}
# g.V().has('airport','code','AUS').out().not(values('code').is('DFW')).out().has('code','SYD').path().by('code'): {'values'}
# g.V().has('airport','code','AUS').out().and(has('code',neq('DFW')): {'neq'}
# g.V().has('airport','code','AUS').out().has('code',without('DFW','LAX')).out().has('code','SYD').path().by('code'): {'without'}
# g.V().has('airport','code','SAT').out().has('code',without('DFW','LAX','PHX','JFK')).out().has('code','SLC').path().by('code'): {'without'}
# g.V().has('code','AUS').out().has('country',without('US','CA')).values('city'): {'values', 'without'}
# g.V().has('code','AUS').out().has('country',within('MX','CA')).values('city'): {'values'}
# g.V().hasLabel('airport').coin(0.5).limit(20).values('code'): {'coin', 'values'}
# g.V().hasLabel('airport').coin(0.05).values('code','elev').fold(): {'coin', 'values', 'fold'}
# g.V().hasLabel('airport').coin(0.5).count(): {'coin'}
# g.V().hasLabel('airport').sample(20).values('code'): {'values', 'sample'}
# g.V().hasLabel('airport').sample(1).id(): {'id', 'sample'}
# g.V().hasLabel('airport').coin(0.01).limit(1): {'coin'}
# g.V().hasLabel('airport').sample(1).id().next(): {'id', 'sample'}
# g.V(x).values('code'): {'values'}
# g.V().hasLabel('airport').id().toList(): {'id'}
# g.V(airports[x-1]).values('code'): {'values'}
# g.V().hasLabel('airport').has('city',startingWith('X')).values('city'): {'startingWith', 'values'}
# g.V().hasLabel('airport').has('city',startingWith('Dal')).values('city').dedup().fold(): {'startingWith', 'values', 'fold'}
# g.V().hasLabel('airport').has('city',startingWith('dal')).count(): {'startingWith'}
# g.V().hasLabel('airport').or(has('city',startingWith('dal')): {'startingWith'}
# g.V().hasLabel('airport').has('city',endingWith('zhi')).values('city'): {'values', 'endingWith'}
# g.V().hasLabel('airport').has('city',containing('gzh')).values('city'): {'containing', 'values'}
# g.V().hasLabel('airport').has('city',notStartingWith('Dal')).count(): {'notStartingWith'}
# g.V().hasLabel('airport').not(has('city',startingWith('Dal'))).count(): {'startingWith'}
# g.V().hasLabel('airport').has('city',notEndingWith('zhi')).count(): {'notEndingWith'}
# g.V().hasLabel('airport').has('city',notContaining('berg')).count(): {'notContaining'}
# g.V().hasLabel('airport').has('city',notContaining('e')).has('city',notContaining('a')).has('city',notContaining('i')).has('city',notContaining('u')).has('city',notContaining('o')).or(has('city',containing('y')): {'containing', 'notContaining'}
# g.V().hasLabel('airport').limit(20).values('code').order().fold(): {'values', 'fold'}
# g.V().hasLabel('airport').order().by('code').limit(20).values('code').fold(): {'values', 'fold'}
# g.V().has('code','AUS').out().order().by('code').values('code','icao').fold(): {'values', 'fold'}
# g.V().hasLabel('airport').limit(20).values('code').order().by(desc).fold(): {'values', 'fold'}
# g.V().hasLabel('airport').limit(20).values('code').order().by(shuffle).fold(): {'values', 'fold'}
# g.V().hasLabel('airport').order().by('longest',desc).valueMap().select('code','longest').limit(10): {'valueMap'}
# g.V().hasLabel('airport').order().by(values('longest'): {'values'}
# g.V().hasLabel('airport').limit(5).group().by('code').by('runways'): {'group'}
# g.V().hasLabel('airport').limit(5).group().by('code').by('runways').order(local).by(keys,asc): {'group'}
# g.V().hasLabel('airport').limit(10).group().by('runways').by('code').order(local).by(keys,desc): {'group'}
# g.V().hasLabel('airport').has('region',within('US-TX','US-LA','US-AZ','US-OK')).order().by('region',asc).valueMap().select('code','region'): {'valueMap'}
# g.V().hasLabel('airport').where(out().count().is(lt(100).and(gt(94)))).group().by('code').by(out().count()): {'where', 'group'}
# g.V().hasLabel('airport').where(and(out().count().is(lt(100)): {'where'}
# g.V().hasLabel('airport').where(out().count().is(between(95,101))).group().by('code').by(out().count()): {'between', 'where', 'group'}
# g.V().hasLabel('airport').where(out().count().is(inside(94,100))).group().by('code').by(out().count()): {'where', 'group', 'inside'}
# g.V().hasLabel('airport').where(out().count().is(lt(100).and(gt(94)))).group().by(out().count()).by('code'): {'where', 'group'}
# g.V().hasLabel('airport').where(out().count().is(lt(100).and(gt(94)).and(neq(97)))).group().by(out().count()).by('code'): {'neq', 'where', 'group'}
# g.V().where(values('runways').is(gt(5))): {'where', 'values'}
# g.V().hasLabel('airport').where(out('route').count().is(gt(60))).count(): {'where'}
# g.V().hasId(lt(47)).outE().and(where(inV().id().is(lt(47))): {'id', 'where'}
# g.V().has('airport','code','AUS').out().not(where(__.in('contains').has('code','US'))).valueMap('code','city'): {'valueMap', 'where'}
# g.V().has('airport','code','AUS').out().has('country',neq('US')).valueMap('code','city'): {'neq', 'valueMap'}
# g.V().has('airport','code','AUS').out().not(has('country','US')).valueMap('code','city'): {'valueMap'}
# g.V().has('airport','code','AUS').out().where(values('runways').is(gt(4).and(neq(6)))).valueMap('code','runways'): {'valueMap', 'neq', 'where', 'values'}
# g.V().has('airport','code','AUS').out().where(values('runways').is(gt(6).or(eq(4)))).valueMap('code','runways'): {'valueMap', 'eq', 'where', 'values'}
# g.V().has('airport','code','AUS').out().where(values('runways').is(gt(6)).or().values('runways').is(4)).valueMap('code','runways'): {'valueMap', 'where', 'values'}
# g.V().has('airport','code','AUS').as('a').out().out().where(neq('a')).path().by('code').limit(10): {'neq', 'where'}
# g.V().has('code','AUS').as('a').out().where(eq('a')).by('runways').valueMap('code','runways'): {'valueMap', 'eq', 'where'}
# g.V().has('code','AUS').as('a').out().as('b').filter(select('a','b').by('runways').where('a',eq('b'))).valueMap('code','runways'): {'valueMap', 'eq', 'where'}
# g.V().has('airport','code','AUS').as('a').out().as('b').where('a',gt('b')).by('runways').valueMap('code','runways'): {'valueMap', 'where'}
# g.V().has('airport','city','London').as('a','r').in('contains').as('b').where('a',eq('b')).by('country').by('code').select('a','r','b').by('code').by('region'): {'eq', 'where'}
# g.V().has('airport','city','London').valueMap('code','region','country'): {'valueMap'}
# g.V().has('code','NCE').values('region').as('r').V().hasLabel('airport').as('a').values('region').where(eq('r')).by().local(select('a').values('city','code','region').fold()): {'where', 'values', 'fold', 'local', 'eq'}
# g.V().has('region','US-TX').choose(values('longest').is(gt(12000)): {'choose', 'values'}
# g.V().hasLabel('airport').choose(values('code').is(within('AUS','DFW')): {'choose', 'values'}
# g.V().hasLabel('airport').limit(10).choose(values('runways').is(lt(4)): {'choose', 'values'}
# g.V().hasLabel('airport').sample(10).as('a').choose(out('route').count().is(gt(50)): {'choose', 'sample'}
# g.V().hasLabel('airport').choose(values('code')).option('DFW',values('desc')).option('AUS',values('region')).option('LAX',values('runways')): {'choose', 'values'}
# g.V().hasLabel('airport').limit(10).choose(values('runways')).option(1,constant('just one')).option(2,constant('a couple')).option(7,constant('lots')).option(none,constant('quite a few')): {'choose', 'values', 'constant'}
# g.V().hasLabel('airport').groupCount().by(choose(values('elev')).option(gt(5000): {'values', 'choose', 'groupCount'}
# g.V().hasLabel('airport').groupCount().by(choose(values('elev').is(gt(5000)): {'values', 'choose', 'groupCount'}
# g.V().has('code','JFK').match(__.as('s').out().as('d'): {'match'}
# g.V().hasLabel('airport').match(__.as('s').out().as('d'): {'match'}
# g.V().hasLabel('airport').match(__.as('a').out().as('b'): {'match'}
# g.V().has('code','AUS').match(__.as('aus').values('runways').as('ausr'): {'match', 'values'}
# g.V().has('code','AUS').as('aus').values('runways').as('ausr').select('aus').out().as('outa').values('runways').as('outr').where('ausr',eq('outr')).select('outa').valueMap().select('code','runways'): {'valueMap', 'eq', 'where', 'values'}
# g.V().has('code','JFK').as('s').out().as('d').where(__.not(out().as('s'))).select('s','d').by('code'): {'where'}
# g.V().has('code','JFK').as('s').out().as('d').where(__.not(out().as('s'))).select('s','d').by('code').select(values): {'where'}
# g.V().hasLabel('airport').as('s').out().as('d').where(__.not(out().as('s'))).limit(10).select('s','d').by('code').order().by(select('s')): {'where'}
# g.V().has('airport','code','DFW').as('a').union(select('a'): {'union'}
# g.V().union(has('airport','code','DFW'): {'union'}
# g.V().has('airport','code','DFW').group().by().by(out().count()): {'group'}
# g.V().has('airport','code','DFW').union(identity(): {'union'}
# g.V().has('airport','code','DFW').union(identity().values('code'): {'values', 'union'}
# g.V(3).union(constant("Hello"): {'constant', 'union'}
# g.V().hasLabel("airport").sample(10).local(union(id(): {'id', 'sample', 'local', 'union'}
# g.V().hasLabel("airport").sample(10).union(id(): {'id', 'sample', 'union'}
# g.V().has('code','AUS').union(__.in().has('country','UK'): {'union'}
# g.V().has('city','London').has('region','GB-ENG').union(out('route').has('city','Paris'): {'union'}
# g.V().has('city','London').has('region','GB-ENG').local(union(__.values('code'): {'values', 'local', 'union'}
# g.V().has('city','London').has('region','GB-ENG').union(outE().inV().has('city','Berlin').outE('route').inV().has('city','Lisbon').path().by('code').by('dist').by('code').by('dist'): {'union'}
# g.V().has('city','Madrid').outE('route').union(values('dist').sum(): {'values', 'union'}
# g.V().has('airport','code','AUS').union(out().has('code','LHR'): {'union'}
# g.V().has('airport','code','AUS').out().has('code',within('LHR','DFW','SYD')).values('code'): {'values'}
# g.V(3).sideEffect(out().count().store('a')).out().out().count().as('b').select('a','b'): {'store'}
# g.V().has('code','SFO').sideEffect{println"I'm working on it"}.values('desc'): {'values'}
# g.V().has('code','AUS').out().aggregate('nonstop').out().where(without('nonstop')).dedup().count(): {'aggregate', 'where', 'without'}
# g.V().has('code','AUS').values().inject('ABIA'): {'values', 'inject'}
# g.V().choose(V().hasLabel('XYZ').count().is(0): {'choose'}
# g.V(3).coalesce(out('fly'): {'coalesce'}
# g.V(1).coalesce(has('region','US-TX').values('desc'): {'coalesce', 'values'}
# g.V(3).coalesce(has('region','US-TX').values('desc'): {'coalesce', 'values'}
# g.V().has('code','AUS').optional(out().has('code','SYD')).values('city'): {'optional', 'values'}
# g.V().has('code','AUS').optional(out().has('code','DFW')).values('city'): {'optional', 'values'}
# g.V().has('code','AUS').coalesce(out().has('code','SYD'): {'coalesce'}
# g.V().has('code','AUS').coalesce(out().has('code','DFW'): {'coalesce'}
# g.V(3).both().order().by(id).fold(): {'fold'}
# g.V(3).both().dedup().order().by(id).fold(): {'fold'}
# g.V(3).bothE().bothV().dedup().order().by(id()).fold(): {'id', 'fold'}
# g.V(3).bothE().otherV().dedup().count(): {'otherV'}
# g.V(3).bothE().otherV().dedup().order().by(id()).fold(): {'otherV', 'id', 'fold'}
# g.V(3).repeat(out()).until(loops().is(2)).count(): {'loops'}
# g.V(3).repeat(out().simplePath()).until(has('code','MIA').or().loops().is(3)).has('code','MIA').path().by('code').limit(5): {'loops'}
# g.V().has('airport','code','AUS').emit().repeat(out().simplePath()).times(2).limit(10).values('code').fold(): {'values', 'fold'}
# g.V().has('code','SAF').repeat('r1',out().simplePath()).until(loops('r1').is(3).or().has('code','MAN')).path().by('city').limit(3).toList(): {'loops'}
# g.V().has('code','SFO').repeat(out().simplePath().groupCount('airports').by(loops())).times(3).cap('airports'): {'cap', 'loops', 'groupCount'}
# g.V().has('code','SFO').repeat(out().simplePath().groupCount('airports').by(loops()).where(select('airports').select(loops()).is(lte(5)))).emit().times(3).path().by('code'): {'loops', 'groupCount', 'where'}
# g.V(1,2,3,4,5).groupCount('x').by(constant('A')).select('x'): {'groupCount', 'constant'}
# g.V(1,2,3,4,5).groupCount('x').by(constant('A')).where(select('x').select('A').is(3)): {'where', 'groupCount', 'constant'}
# g.V(1,2,3,4,5).groupCount('x').by(constant('A')).where(select('x').select('A').is(lte(3))): {'where', 'groupCount', 'constant'}
# g.V().has('code','AUS').out().out().cyclicPath().limit(10).path().by('code'): {'cyclicPath'}
# g.V().has('code','AUS').repeat(out('route')).until(cyclicPath()).limit(10).path().by('code'): {'cyclicPath'}
# g.V().has('code','AUS').out().out().not(cyclicPath()).limit(10).path().by('code'): {'cyclicPath'}
# g.V().has('code','AUS').as('a').out().out().where(neq('a')).limit(10).path().by('code'): {'neq', 'where'}
# g.V(3).as('a').addE('loop').to('a'): {'to', 'addE'}
# g.V().out().cyclicPath().path(): {'cyclicPath'}
# g.V().outE().inV().cyclicPath().path(): {'cyclicPath'}
# g.V().hasLabel('airport').group().by('code').by(out('route').count()): {'group'}
# g.V().hasLabel('airport').group().by('code').by(out('route').count()).select('LHR','JFK','DFW'): {'group'}
# g.V().hasLabel('airport').group().by('code').by(__.in('route').count()).select('LHR','JFK','DFW'): {'group'}
# g.V().hasLabel('airport').group().by('code').by(out().count()).order(local).by(values).unfold().tail(10).fold(): {'unfold', 'group', 'fold', 'tail'}
# g.V().hasLabel('airport').limit(10).project("v","degree").by('code').by(bothE('route').count()): {'project'}
# g.V().hasLabel('airport').limit(10).group().by('code').by(bothE('route').count()): {'group'}
# g.V().limit(1).math('100/2'): {'math'}
# g.V().has('airport','code','DFW').values('runways'): {'values'}
# g.V().has('airport','code','SFO').values('runways'): {'values'}
# g.V().has('airport','code','DFW').as('a').out().has('code','SFO').as('b').math('a + b').by('runways'): {'math'}
# g.V(3).out().count().math('_ / 2'): {'math'}
# g.V(3).out().count().math('_ % 5'): {'math'}
# g.V(3).out().count().as('a').math('a / 2'): {'math'}
# g.V().has('code','SAF').as('a').out().as('b').select('a','b').by(values('code','runways').fold()): {'values', 'fold'}
# g.V().has('code','SAF').as('a').out().as('b').math('a + b').by('runways'): {'math'}
# g.V().has('code','DFW').values('longest').math('_ * 0.3048'): {'math', 'values'}
# g.V().has('code','DFW').project('Longest runway at','feet','meters').by('code').by('longest').by(values('longest').math('_ * 0.3048')): {'project', 'values', 'math'}
# g.V().hasLabel('airport').sample(12).project('IATA','city','position').by('code').by('city').by(choose(values('lon').math('signum(_): {'signum', 'values', 'sample', 'project', 'choose', 'math'}
# g.V().hasLabel('airport').values('runways').mean().next(): {'values'}
# g.V().hasLabel('airport').groupCount().by('runways'): {'groupCount'}
# g.V().hasLabel('airport').local(out().count()).mean().next(): {'local'}
# g.V().hasLabel('airport').values('runways').fold().as('runways').mean(local).as('mean').select('runways').unfold().math('(_-mean): {'math', 'unfold', 'values', 'fold'}
# g.V().has('code','AUS').project('in','out').by(__.in('route').count()).by(out('route').count()): {'project'}
# g.V().has('code','AUS').project('in','out').by(__.in('route').count()).by(out('route').count()).math('in + out'): {'project', 'math'}
# g.V().has('region','US-OK').values('code').withIndex(): {'values', 'withIndex'}
# g.V().has('region','US-OK').values('code').withIndex(1): {'values', 'withIndex'}
# g.V().has('region','US-OK').values('code').indexed(1): {'values', 'indexed'}
# g.V().has('code','LHR').out().limit(5).values('code').index(): {'index', 'values'}
# g.V().has('code','LHR').out().limit(5).values('code').fold().index(): {'index', 'values', 'fold'}
# g.V().has('code','LHR').out().limit(5).values('code').fold().index().unfold(): {'index', 'unfold', 'values', 'fold'}
# g.V().has('code','LHR').out().limit(5).values('code').fold().index().with(WithOptions.indexer,WithOptions.map): {'index', 'with', 'values', 'fold'}
# g.V().has('code','LHR').out().limit(5).values('code').fold().index().with(WithOptions.indexer,WithOptions.list).unfold().order().by(tail(local,1): {'index', 'unfold', 'values', 'tail', 'fold', 'with'}
# g.V().has('code','SAF').out().values('code').fold().index(): {'index', 'values', 'fold'}
# g.V().has('code','SAF').out().values('code').fold().index().unfold().order().by(tail(local,1): {'index', 'unfold', 'values', 'tail', 'fold'}
# g.V().has('continent','code','EU').out('contains').values('code').order().fold(): {'values', 'fold'}
# g.V().where(values('runways').is(gte(6))).values('code'): {'where', 'values'}
# g.V().has('runways',gte(6)).values('code'): {'values'}
# g.V().has('code','DFW').outE().as('a').inV().has('code','AUS').select('a').values('dist'): {'values'}
# g.V().has('code','BNE').out().as('stop').out().has('code','AUS').select('stop').values('code'): {'values'}
# g.V().hasLabel('airport').where(out('route').count().is(lt(5))).count(): {'where'}
# g.V().hasLabel("airport").where(outE('route').count().is(gt(200))).values('code'): {'values', 'where'}
# g.V().hasLabel("airport").filter(outE("route").count().is(gt(200))).values('code'): {'values'}
# g.V().as('a').outE().has('dist',eq(100)).limit(10).inV().as('b').select('a','b').by('code'): {'eq'}
# g.V().outE().has('dist',eq(100)).limit(10).inV().path().by('code').by('dist'): {'eq'}
# g.V().has('airport','elev',gt(10000)).order().by('elev',asc).valueMap('city','elev'): {'valueMap'}
# g.V().has('airport','elev',gt(10000)).order().by('elev',asc).project('city','elevation').by('city').by('elev'): {'project'}
# g.V().hasLabel('airport').where(__.in('contains').has('code','AF')).as('a').out().has('country','US').as('b').select('a','b').by('code'): {'where'}
# g.V().has('code','AUS').out().project('ap','rw').by('code').by('runways').order().by(select('rw'): {'project'}
# g.V().has('code','AUS').union(in(): {'union'}
# g.V().has('code','AUS').union(__.in(): {'union'}
# g.V().has('country','code','PT').out("contains").values('city'): {'values'}
# g.V().has('airport','country','PT').values('city'): {'values'}
# g.V().has('code',from).outE().as('a').inV().has('code',to).select('a').values('dist').next(): {'values'}
# g.V().has(id,a).values('code').next(): {'values'}
# g.V().group().by(label).by('code').next(): {'group'}
# g.V().group().by('code').next(): {'group'}
# g.V().has('airport','country','DE').fill(german): {'fill'}
# g.V(german[1]).values('city'): {'values'}
# g.V(a).out().has('country','DE').values('code'): {'values'}
# g.V(it).out().values('code').toList(): {'values'}
# g.V().hasLabel('airport').values('code').toList(): {'values'}
# g.addV('airport').property('code','XYZ').property('icao','KXYZ').property('desc','This is not a real airport').next(): {'addV'}
# g.V().has('code','DFW').addE('route').to(xyz): {'to', 'addE'}
# g.V().has('code','DFW').addE('route').to(V().has('code','XYZ')): {'to', 'addE'}
# g.V().has('code','DFW').addE('route').from(xyz): {'from', 'addE'}
# g.V().has('code','XYZ').as('a').V().has('code','DFW').addE('route').to('a'): {'to', 'addE'}
# g.addV(V().has('code','AUS').label()).property('code','XYZ'): {'addV'}
# g.V(53768).valueMap(true): {'valueMap'}
# g.V(53768).addE(V().has('code','AUS').outE().limit(1).label()).to(V().has('code','AUS')): {'to', 'addE'}
# g.E(53770).valueMap(true): {'valueMap'}
# g.V().has('code','AUS').property('places',out().values('code').fold()): {'values', 'fold'}
# g.V().has('code','AUS').valueMap('places'): {'valueMap'}
# g.V().has('code','AUS').values('places').next().size(): {'size', 'values'}
# g.V().has('code','AUS').values('places').next(): {'values'}
# g.addV().property(id,99999L): {'addV'}
# g.addV().property(id,n): {'addV'}
# g.addV('airport').property('code','AUS').as('aus').addV('airport').property('code','DFW').as('dfw').addV('airport').property('code','LAX').as('lax').addV('airport').property('code','JFK').as('jfk').addV('airport').property('code','ATL').as('atl').addE('route').from('aus').to('dfw').addE('route').from('aus').to('atl').addE('route').from('atl').to('dfw').addE('route').from('atl').to('jfk').addE('route').from('dfw').to('jfk').addE('route').from('dfw').to('lax').addE('route').from('lax').to('jfk').addE('route').from('lax').to('aus').addE('route').from('lax').to('dfw'): {'addV', 'addE', 'from', 'to'}
# g.addV("airport").property("code",a[0],"iata",a[1]).next(): {'addV'}
# g.addV("airport").property("code",it[0],"iata",it[1]).next(): {'addV'}
# g.V().has('code','XYZ').fold(): {'fold'}
# g.V().has('code','XYZ').fold().coalesce(unfold(): {'unfold', 'coalesce', 'fold'}
# g.V(3).fold().coalesce(unfold().property('runways',3): {'unfold', 'coalesce', 'fold'}
# g.V(3).valueMap().unfold(): {'unfold', 'valueMap'}
# g.V(9999999).fold().coalesce(unfold().property('runways','3'): {'unfold', 'coalesce', 'fold'}
# g.V(57343).valueMap().unfold(): {'unfold', 'valueMap'}
# g.V().has('code','XYZ').drop(): {'drop'}
# g.V().has('code','AUS').outE().as('e').inV().has('code','LHR').select('e').drop(): {'drop'}
# g.V().has('code','LHR').outE().as('e').inV().has('code','AUS').select('e').drop(): {'drop'}
# g.V().has('code','SFO').valueMap(): {'valueMap'}
# g.V().has('code','SFO').properties('desc').drop(): {'drop'}
# g.V().has('code','SFO').properties().drop(): {'drop'}
# g.E().drop(): {'drop'}
# g.V().drop(): {'drop'}
# g.V().has('airport','code','DFW').properties().key(): {'key'}
# g.V().has('code','DFW').outE().properties().key().dedup(): {'key'}
# g.V().hasLabel("airport").properties("runways","longest").group().by(key).by(value().sum()): {'group'}
# g.V().has('code','AUS').propertyMap(): {'propertyMap'}
# g.V().properties().hasValue('London'): {'hasValue'}
# g.V().properties().hasValue('London').id(): {'id', 'hasValue'}
# g.V().properties().hasId(583).key(): {'key'}
# g.V().properties().hasId(583).next().element(): {'element'}
# g.V().properties().hasId(583).next().element().values('desc'): {'element', 'values'}
# g.V().has('airport','code','DFW').properties('city').next().graph(): {'graph'}
# g.V(4).properties('city').id(): {'id'}
# g.addV().property('code','AUS').property('code','KAUS'): {'addV'}
# g.V().has('code','AUS').valueMap(): {'valueMap'}
# g.V().has('code','KAUS').valueMap(): {'valueMap'}
# g.V().has('code','AUS').values(): {'values'}
# g.V().properties().hasValue('AUS'): {'hasValue'}
# g.addV().property('one','hi').property('one','hello').property('two','goodbye').property('one','hello again').valueMap(): {'addV', 'valueMap'}
# g.addV().next(): {'addV'}
# g.V(v).property('one','hi').property('one','hello').property('two','goodbye').property('one','hello again').valueMap(): {'valueMap'}
# g.addV().property('one','hi').property('one','hello').property('two','goodbye').property('one','hello again').explain(): {'addV', 'explain'}
# g.V(v).property('one','hi').property('one','hello').property('two','goodbye').property('one','hello again').explain(): {'explain'}
# g.V().has('code','AUS').properties().hasValue('ABIA').drop(): {'hasValue', 'drop'}
# g.V().has('code','AUS').properties('code').drop(): {'drop'}
# g.addV('test').property('dups','one').property('dups','two').property('dups','one'): {'addV'}
# g.V().hasLabel('test').valueMap(): {'valueMap'}
# g.V(3).valueMap('hw'): {'valueMap'}
# g.V().has('code','AUS').valueMap('x'): {'valueMap'}
# g.V().has('code','AUS').properties().hasValue('AUS').property('date','6/6/2017'): {'hasValue'}
# g.V().has('code','AUS').properties().hasValue('AUS').properties('date'): {'hasValue'}
# g.V().has('code','AUS').properties().hasValue('AUS').property('date','6/6/2017').drop(): {'hasValue', 'drop'}
# g.V().has('code','AUS').properties('code').properties('date').drop(): {'drop'}
# g.V().has('code','AUS').properties().valueMap(): {'valueMap'}
# g.V().has('code','AUS').properties().valueMap().with(WithOptions.tokens,WithOptions.values): {'with', 'valueMap'}
# g.V().has('code','AUS').properties().valueMap().with(WithOptions.tokens,WithOptions.keys): {'with', 'valueMap'}
# g.V().has('code','AUS').properties().valueMap().with(WithOptions.tokens,WithOptions.all): {'with', 'valueMap'}
# g.V().hasLabel('airport').limit(1).next().keys(): {'keys'}
# g.E().hasLabel('route').limit(1).next().keys(): {'keys'}
# g.V().hasLabel('airport').limit(1).values(it).next().class): {'values'}
# g.V(1..5).group().by('code').by('runways'): {'group'}
# g.V().hasLabel('airport').limit(40).groupCount().by('region'): {'groupCount'}
# g.V().hasLabel('airport').limit(20).values('runways').fold().order(local): {'values', 'fold'}
# g.V().has('airport','country','IE').project('loc','iata').by('city').by('code'): {'project'}
# g.V().has('code','DFW').project('dfw','route_count').by().by(outE().count()): {'project'}
# g.V().has('region','US-TX').store('r').by('runways').cap('r'): {'cap', 'store'}
# g.V().has('airport','country','IE').aggregate('ireland').cap('ireland'): {'cap', 'aggregate'}
# g.V().has('airport','country','IE').aggregate('ireland').out().where(without('ireland')).values('country').dedup().fold().order(local): {'without', 'values', 'where', 'fold', 'aggregate'}
# g.V().has('airport','country','IE').store('a').limit(2).cap('a'): {'cap', 'store'}
# g.V().has('airport','country','IE').aggregate('a').limit(2).cap('a'): {'cap', 'aggregate'}
# g.V().has('airport','country','IE').aggregate('ireland').by('runways').cap('ireland'): {'cap', 'aggregate'}
# g.V(1..5).group().by('code').by('runways').next().getClass(): {'getClass', 'group'}
# g.V(1..5).aggregate('a').cap('a').next().getClass(): {'cap', 'getClass', 'aggregate'}
# g.V().hasLabel('airport').limit(5).group().by('code').by('city'): {'group'}
# g.V().hasLabel('airport').limit(5).group().by('code').by('city').count(local): {'group'}
# g.V().hasLabel('airport').limit(5).group().by('code').by('city').select(keys): {'group'}
# g.V().hasLabel('airport').limit(5).group().by('code').by('city').select(values): {'group'}
# g.V().has('code','DFW').project('dfw','route_count').by().by(outE().count()).select(values): {'project'}
# g.V().has('code','DFW').project('dfw','route_count').by().by(outE().count()).select(keys): {'project'}
# g.V().has('code','DFW').project('dfw','route_count').by().by(outE().count()).select('route_count'): {'project'}
# g.V().has('code','DFW').project('dfw','route_count').by().by(outE().count()).select('dfw'): {'project'}
# g.V().has('code','DFW').project('dfw','route_count').by().by(outE().count()).select('dfw').values('desc'): {'project', 'values'}
# g.V().hasLabel('airport').limit(5).group().by('code').by('city').unfold(): {'unfold', 'group'}
# g.V().hasLabel('airport').limit(5).group().by('code').by('city').select(values).unfold(): {'unfold', 'group'}
# g.V().hasLabel('airport').limit(5).group().by('code').by('city').select(values).unfold().unfold(): {'unfold', 'group'}
# g.V().hasLabel('airport').limit(5).group().by('code').by('city').select(values).repeat(unfold()).times(2): {'unfold', 'group'}
# g.V().hasLabel('airport').limit(5).group().by('code').by('city').select(values).repeat(unfold()).until(count(local).is(1)).unfold(): {'unfold', 'group'}
# g.V().hasLabel('airport').limit(5).group().by('code').by('city').select(values).unfold().unfold().fold(): {'unfold', 'group', 'fold'}
# g.V(3).valueMap().select(keys): {'valueMap'}
# g.V(3).valueMap().select(values): {'valueMap'}
# g.V().has('airport','country','IE').group().by('code').by('runways'): {'group'}
# g.V().has('airport','country','IE').group().by('code').by('runways').select(keys): {'group'}
# g.V().has('airport','country','IE').group().by('code').by('runways').select(keys).order(local): {'group'}
# g.V().has('airport','country','IE').group().by('code').by('runways').select(keys).unfold().order().fold(): {'unfold', 'group', 'fold'}
# g.V().has('airport','country','IE').group().by('code').by('runways').select(keys).limit(local,2): {'group'}
# g.V().has('airport','country','IE').group().by('code').by('runways').select(keys).tail(local,3): {'group', 'tail'}
# g.V().has('airport','country','IE').group().by('code').by('runways').select(keys).range(local,3,5): {'group', 'range'}
# g.V().has('region','US-TX').values('code').fold(): {'values', 'fold'}
# g.V().has('region','US-TX').values('code').fold().limit(local,2): {'values', 'fold'}
# g.V().has('region','US-TX').values('code').fold().tail(local,2): {'values', 'fold', 'tail'}
# g.V().has('country','US').dedup().by('region').values('region').order().fold(): {'values', 'fold'}
# g.V().has('country','US').values('region').order().fold().dedup(local): {'values', 'fold'}
# g.V().has('code','AUS').both().group().by(label).by(values('code').fold().dedup(local).order(local)): {'values', 'fold', 'group'}
# g.V().has('code','AUS').both().group().by(label).by(values('code').fold().dedup(local).order(local).limit(local,10)): {'values', 'fold', 'group'}
# g.V().has('code','DFW').group().by().by(outE().count()): {'group'}
# g.V().has('code','DFW').as('a').group().by().by(outE().count()).select('a'): {'group'}
# g.V().has('code','DFW').group().by().by(outE().count()).select(keys): {'group'}
# g.V().has('code','DFW').group().by().by(outE().count()).unfold().select(keys): {'unfold', 'group'}
# g.V().has('code','DFW').group().by().by(outE().count()).unfold().select(values): {'unfold', 'group'}
# g.V().has('code','DFW').group().by().by(outE().count()).unfold().select(keys).values('code'): {'unfold', 'values', 'group'}
# g.V().has('code','DFW').group().by().by(outE().count()).as('ct').addV('dfwcount').property('current_count',select('ct').unfold().select(values)): {'addV', 'unfold', 'group'}
# g.V(54931).valueMap(true): {'valueMap'}
# g.V().hasLabel('airport').limit(10).group().by('code').by(values('runways')).order(local).by(values): {'values', 'group'}
# g.V().hasLabel('airport').limit(10).group().by('code').by(values('runways')).unfold().select(values).sum(): {'unfold', 'values', 'group'}
# g.V().hasLabel('airport').limit(10).group().by('code').by(values('runways')).local(select(values).sum(local)): {'values', 'group', 'local'}
# g.V().hasLabel('airport').limit(10).group().by('code').by(values('runways')).unfold().select(values).sum().math('_ / 10'): {'math', 'unfold', 'values', 'group'}
# g.V().hasLabel('airport').limit(10).group().by('code').by(values('runways')).project('total','number').by(select(values).unfold().sum()).by(count(local)).math('total / number'): {'unfold', 'values', 'project', 'group', 'math'}
# g.V().has('region','US-NM').group().by('code').by(values('runways')): {'values', 'group'}
# g.V().has('region','US-AZ').group().by('code').by(values('runways')): {'values', 'group'}
# g.V().has('region','US-NM').group().by('code').by(values('runways')).select(values).unfold().sum().store('a').V().has('region','US-AZ').group().by('code').by(values('runways')).select(values).unfold().sum().store('b').project('first','second').by(select('a').unfold()).by(select('b').unfold()).math('first / second'): {'unfold', 'values', 'store', 'project', 'group', 'math'}
# g.V().has('code','SAF').out().values('runways').fold(): {'values', 'fold'}
# g.V().sack(assign).by(constant(1)).has('code','SAF').out().values('runways').sack(sum).sack().fold(): {'values', 'sack', 'fold', 'constant'}
# g.V().has('code','AUS').sack(assign).by('runways').V().has('code','SAF').out().sack(sum).by('runways').sack().fold(): {'sack', 'fold'}
# g.V().has('code','AUS').sack(assign).by('runways').V().has('code','SAF').out().sack(mult).by('runways').sack().fold(): {'sack', 'fold'}
# g.V().has('code','AUS').sack(assign).by('runways').V().has('code','SAF').out().sack(minus).by('runways').sack().fold(): {'sack', 'fold'}
# g.V().sack(assign).by(constant(-1)).has('code','SAF').out().values('runways').sack(sum).sack().fold(): {'values', 'sack', 'fold', 'constant'}
# g.V().sack(assign).by(constant(400)).has('code','SAF').outE().sack(min).by('dist').sack().fold(): {'sack', 'fold', 'constant'}
# g.V().sack(assign).by(constant(400)).has('code','SAF').outE().sack(max).by('dist').sack().fold(): {'sack', 'fold', 'constant'}
# g.V().has('code','SAF').repeat(outE().inV().simplePath()).times(2).limit(10).project('path','total').by(path().by('code').by('dist')).by(path().unfold().coalesce(values('dist'): {'project', 'values', 'unfold', 'coalesce'}
# g.V().has('code','SAF').repeat(outE().inV().simplePath()).times(2).limit(10).local(union(path().by('code').by('dist').unfold(): {'unfold', 'local', 'union'}
# g.V().has('code','AUS').repeat(out().simplePath()).until(has('code','WLG')).limit(10).local(union(path().by('code'): {'local', 'union'}
# g.V(3).sack(assign).by(constant(true)).sack(and).by(constant(false)).sack(): {'sack', 'constant'}
# g.V(3).sack(assign).by(constant(true)).sack(or).by(constant(false)).sack(): {'sack', 'constant'}
# g.addV('happy').property('happy',true): {'addV'}
# g.addV('sad').property('happy',false): {'addV'}
# g.V(3).sack(assign).by(constant(true)).sack(and).by(V().hasLabel('happy').values('happy')).sack().path(): {'values', 'sack', 'constant'}
# g.V(3).sack(assign).by(constant(true)).sack(and).by(V().hasLabel('sad').values('happy')).sack().path(): {'values', 'sack', 'constant'}
# g.V().has('airport','runways',gt(6)).values('code'): {'values'}
# g.V().has('region','US-OR').sideEffect{c+=1}.values('code').fold(): {'values', 'fold'}
# g.V().has('region','US-OR').values('code').count().next(): {'values'}
# g.V().has('region','US-OR').values('code').fill(oregon): {'fill', 'values'}
# g.V().hasLabel('airport').filter{it.get().property('city').value(): {'get'}
# g.V().has('runways',6).sideEffect{printit.get().values('code').next(): {'get', 'values'}
# g.V().hasLabel('airport').filter{it.get().value('city').startsWith('Dal'): {'get', 'startsWith'}
# g.V().hasLabel('airport').as('a').values('desc').filter{it.toString().contains('F.'): {'values', 'toString'}
# g.V().hasLabel('airport').limit(10).map(properties('city')): {'map'}
# g.V().hasLabel('airport').limit(10).map(properties('city').group().by(key()).by(value())): {'map', 'group', 'key'}
# g.V().hasLabel('airport').limit(10).map(properties('city').group().by(key()).by(value())).unfold().order().by(values,asc): {'map', 'unfold', 'group', 'key'}
# g.V().hasLabel('airport').limit(10).map(values('city')).fold(): {'map', 'values', 'fold'}
# g.V().hasLabel('airport').limit(10).values('city').fold(): {'values', 'fold'}
# g.V().hasLabel('airport').limit(10).id().fold(): {'id', 'fold'}
# g.V().hasLabel('airport').limit(10).map{it.get().id(): {'get', 'id'}
# g.V().hasLabel('airport').limit(10).map{a=1;b=2;c=a+b;it.get().id(): {'get', 'id'}
# g.V().has('code','SAF').out().values('runways').map{it.get(): {'get', 'values'}
# g.V().has('code','SAF').out().map{m=[:];m[it.get().values('code').next(): {'get', 'values'}
# g.V().has('code','SAF').map(out()): {'map'}
# g.V().has('code','SAF').flatMap(out()): {'flatMap'}
# g.V().has('code','AUS').flatMap(outE().inV()).path().by('city').limit(3): {'flatMap'}
# g.V().has('code','AUS').map(outE().inV()).path().by('city').limit(3): {'map'}
# g.V().has('code','AUS').repeat(flatMap(outE().has('dist',gt(2000)).inV())).times(2).path().limit(5): {'flatMap'}
# g.V().hasLabel('airport').filter{it.get().property('desc').value().contains('Dallas'): {'get'}
# g.V().has('airport','type','airport').filter{it.get().property('city').value==~/Dallas|Austin/}.values('code'): {'get', 'values'}
# g.V().has('airport','type','airport').filter{it.get().property('city').value(): {'get'}
# g.V().hasLabel('airport').values('longest').mean().next(): {'values'}
# g.V().hasLabel('airport').has('longest',test(f,a)).values('code'): {'test', 'values'}
# g.V().has('desc',test(f,/^Dal.*/)).values('desc'): {'test', 'values'}
# g.V().has('desc',regex(/^Dal.*/)).values('desc'): {'values', 'regex'}
# g.V().has('code','SFO').valueMap().map(unfold().group().by(keys).by(select(values).unfold())).unfold(): {'valueMap', 'map', 'unfold', 'group'}
# g.V().has('code','SFO').valueMap('region'): {'valueMap'}
# g.V().has('code','SFO').valueMap().map(unfold().group().by(keys).by(choose(select(values).count(local).is(1): {'unfold', 'choose', 'group', 'map', 'valueMap'}
# g.V().has('code','AUS').repeat(out()).times(2).tree().by('code').next(): {'tree'}
# g.V(1..46).outE().filter(inV().hasId(within(1L..46L))).subgraph('a').cap('a').next(): {'cap', 'subgraph'}
# g.V().has('code','AUS').bothE().subgraph('subGraph').cap('subGraph').next(): {'cap', 'subgraph'}
# g.V().has('code','AUS').outE('route').subgraph('subGraph').cap('subGraph').next(): {'cap', 'subgraph'}
# g.V().has('code','AUS').repeat(bothE().subgraph('subGraph').outV()).times(2).cap('subGraph').next(): {'cap', 'subgraph'}
# g.V().hasLabel('continent').has('code','EU').outE('contains').subgraph('eu-air-routes').inV().as('a').inE('contains').subgraph('eu-air-routes').outV().hasLabel('country').select('a').outE().as('r').inV().hasLabel('airport').in().hasLabel('continent').has('code','EU').select('r').subgraph('eu-air-routes').cap('eu-air-routes').next(): {'cap', 'subgraph'}
# g.V().has('code','LAX').valueMap(true,'code','city').next(): {'valueMap'}
# g.V().has('code','AUS').as('a').repeat(out().where(neq('a'))).times(1).simplePath().has('code','LAX').path().by('code').count().next(): {'neq', 'where'}
# g.V().has('code','AUS').as('a').repeat(out().where(neq('a'))).times(2).simplePath().has('code','LAX').path().by('code').count().next(): {'neq', 'where'}
# g.V().has('code','AUS').as('a').repeat(out().where(neq('a'))).times(3).simplePath().has('code','LAX').path().by('code').count().next(): {'neq', 'where'}
# g.V().has('code','AUS').as('a').repeat(out().where(neq('a'))).times(4).simplePath().has('code','LAX').path().by('code').count().next(): {'neq', 'where'}
# g.V().has('region','US-TX').out().has('region','US-CA').out().has('country','DE').profile(): {'profile'}
# g.V().has('airport','code','AUS').repeat(out()).until(has('code','AGR')).limit(10).path().by('code').profile(): {'profile'}
# g.V().has('code','IST').valueMap(true): {'valueMap'}
# g.V().hasLabel('country').not(out()).values('desc'): {'values'}
# g.V().hasLabel('country').where(out().count().is(0)).values('desc'): {'values', 'where'}
# g.V().hasLabel('country').where(__.not(out())).values('desc'): {'values', 'where'}
# g.V().hasLabel('airport').not(bothE('route')).values('code').fold(): {'values', 'fold'}
# g.V().hasLabel('airport').where(out('route').count().is(gt(180))).values('code').fold(): {'values', 'where', 'fold'}
# g.V().hasLabel('airport').where(out('route').count().is(gt(180))).group().by('code').by(out().count()): {'where', 'group'}
# g.V().hasLabel('airport').where(out('route').count().is(gt(180))).group().by('code').by(out().count()).order(local).by(values,desc): {'where', 'group'}
# g.V().hasLabel('airport').where(both('route').count().is(gt(400))).values('code').fold(): {'values', 'where', 'fold'}
# g.V().hasLabel('airport').where(out().count().is(eq(1))).count(): {'eq', 'where'}
# g.V().hasLabel('airport').groupCount().by('runways').unfold().project('runways','count').by(keys).by(values): {'project', 'unfold', 'groupCount'}
# g.V().hasLabel('airport').groupCount().by('runways').project('runways','count').by(keys).by(values): {'project', 'groupCount'}
# g.V().has('country','code','UK').out('contains').groupCount().by('region'): {'groupCount'}
# g.V().hasLabel('airport').groupCount().by('country').order(local).by(values,desc): {'groupCount'}
# g.V().hasLabel('airport').groupCount().by('country').order(local).by(keys,asc): {'groupCount'}
# g.V().hasLabel('airport').groupCount().by('country').select('DE','CN','NL','US'): {'groupCount'}
# g.V().hasLabel('country').group().by('code').by(outE().count()).order(local).by(values,desc): {'group'}
# g.V().hasLabel('country').group().by('code').by(outE().count()).order(local).by(values,desc).tail(local,20): {'group', 'tail'}
# g.V().hasLabel('airport').out().groupCount().by('code'): {'groupCount'}
# g.V().hasLabel('airport').out().groupCount().by('code').select('AUS','AMS','JFK','DUB','MEX'): {'groupCount'}
# g.V().hasLabel('airport').group().by(out().count()).by('code').order(local).by(keys): {'group'}
# g.V().hasLabel('airport').group().by(out().count()).by('code').next().get(105L): {'get', 'group'}
# g.V(3).out().groupCount('a').by('runways').out().count().as('b').select('a','b'): {'groupCount'}
# g.V().has('airport','region','US-OK').groupCount('a').by(constant('OK')).cap('a'): {'cap', 'groupCount', 'constant'}
# g.V().has('airport','region','US-OK').groupCount().by('region'): {'groupCount'}
# g.V().hasLabel('airport').choose(has('runways',4): {'choose'}
# g.V().hasLabel("airport").limit(5).group().by('code').by(out("route").limit(5).group().by('code').by(out("route").count())): {'group'}
# g.V().hasLabel("airport").limit(5).group().by('code').by(out("route").limit(5).group().by('code').by(out("route").count())).select('ANC','ATL'): {'group'}
# g.V().hasLabel("airport").limit(5).group().by('code').by(out("route").limit(5).group().by('code').by(out("route").count())).select('ANC').select('IAH','LAX'): {'group'}
# g.V().has('continent','code','EU').out().out().has('country','US').groupCount().by('code').order(local).by(values,asc): {'groupCount'}
# g.V().has('continent','code','EU').out().as('a').out().has('country','US').select('a').groupCount().by('code').order(local).by(values,asc): {'groupCount'}
# g.V().has('code','AUS').out('route').values('city').fold(): {'values', 'fold'}
# g.V().has('code','AUS').out('route').values('city').fold(0): {'values', 'fold'}
# g.V().hasLabel('airport').groupCount().by(out('route').count()).order(local).by(values,desc): {'groupCount'}
# g.V().hasLabel('airport').groupCount().by(out('route').count()).order(local).by(keys,asc): {'groupCount'}
# g.V().hasLabel('airport').union(count(): {'union'}
# g.V().has('type','airport').local(__.in('route').count()).mean(): {'local'}
# g.V().has('type','airport').local(both('route').count()).mean(): {'local'}
# g.V().has('region','GB-ENG').has('city','London').group().by('code').by(out().count()): {'group'}
# g.V().has('region','GB-ENG').has('city','London').aggregate('lon').out().out().dedup().where(without('lon')).count(): {'aggregate', 'where', 'without'}
# g.V().has('region','GB-ENG').order().by('code').aggregate('a').out().where(within('a')).path().by('code'): {'aggregate', 'where'}
# g.V().has('region','GB-ENG').order().by('code').as('a').out().has('region','GB-ENG').as('b').where('a',lt('b')).by('code').path().by('code'): {'where'}
# g.V().has('airport','runways',gte(6)).values('code','runways').fold(): {'values', 'fold'}
# g.V().has('airport','runways',gte(6)).local(values('code','runways').fold()): {'values', 'fold', 'local'}
# g.V().where(outE().count().is(0)).count(): {'where'}
# g.V().has('code','AUS').repeat(out().has('code',without('YYZ')).dedup()).until(has('code','YPO')).path().by('code'): {'without'}
# g.V().has('code','FLL').out().as('a').in('contains').has('code','EU').select('a').values('city'): {'values'}
# g.V().has('code','DEN').out().has('country','MX').values('city'): {'values'}
# g.V().has('city',within('London','Munich','Paris')).aggregate('a').out().where(within('a')).path().by('code'): {'aggregate', 'where'}
# g.V().has('code','LGW').outE().where(values('dist').is(gt(4000L))).inV().path().by('code').by('dist').by('city'): {'values', 'where'}
# g.V().hasLabel('airport').has('code','DFW').outE().has('dist',gt(4500)).as('e').inV().as('c').select('e','c').by('dist').by('code').sort(): {'sort'}
# g.V().as('a').outE().has('dist',gt(8000)).inV().as('b').filter(select('a','b').by('code').where('a',lt('b'))).path().by('code').by('dist'): {'where'}
# g.V().as('a').outE().has('dist',gt(8000)).order().by('dist',desc).inV().as('b').filter(select('a','b').by('code').where('a',lt('b'))).path().by('code').by('dist'): {'where'}
# g.V().as('s').outE().has('dist',gt(8000)).order().by('dist',desc).inV().as('f').where('f',lt('s')).by('code').path().by('code').by('dist'): {'where'}
# g.V().as('s').outE().has('dist',gt(8000)).order().by('dist',desc).inV().as('f').where('f',gt('s')).by('code').path().by('code').by('dist'): {'where'}
# g.E().hasLabel('route').order().by('dist',desc).limit(40).project('a','b','c').by(inV().values('code')).by('dist').by(outV().values('code')).filter(select('a','c')).where('a',lt('c')): {'project', 'where', 'values'}
# g.V().hasLabel('airport').as('a').outE().as('b').order().by('dist',desc).limit(40).inV().as('c').where('a',lt('c')).by('code').select('a','b','c').by('code').by('dist'): {'where'}
# g.V().hasLabel('airport').limit(10).local(outE().order().by('dist',desc).inV().path().by('code').by('dist').limit(1)): {'local'}
# g.V().has('city',within('London','Munich','Paris')).aggregate('a').outE().union(values('dist').sum(): {'aggregate', 'values', 'union'}
# g.V().has('code','AUS').outE().as('e').inV().has('code','MEX').select('e').values('dist'): {'values'}
# g.V().hasLabel('airport').where(out().count().is(gt(200))).group().by('code').by(outE().count()): {'where', 'group'}
# g.V().hasLabel('airport').where(out().count().is(gt(200))).group().by('code').by(outE().count()).order(local).by(values): {'where', 'group'}
# g.V().has('code','AUS').sack(assign).by(constant(0)).out().sack(sum).by('runways').sack().sum(): {'sack', 'constant'}
# g.V().filter(values('lat').is(gt(77))).valueMap('city','lat'): {'valueMap', 'values'}
# g.V().has('lat',gt(77)).valueMap('city','lat'): {'valueMap'}
# g.V().has('lat',outside(-50,77)).order().by('lat',asc).valueMap('city','lat'): {'valueMap', 'outside'}
# g.V().has('airport','code','LHR').valueMap('lat','lon'): {'valueMap'}
# g.V().has('airport','city','London').has('region','GB-ENG').valueMap('code','lat','lon'): {'valueMap'}
# g.V().hasLabel('airport').has('lon',between(-0.1,0.1)).valueMap('code','lon'): {'between', 'valueMap'}
# g.V().hasLabel('airport').has('lat',between(-0.1,0.1)).valueMap('code','lat'): {'between', 'valueMap'}
# g.V().has('code','LHR').values('lat').next(): {'values'}
# g.V().has('code','LHR').values('lon').next(): {'values'}
# g.V().hasLabel('airport').where(and(values('lon').is(between(lon-1,lon+1)): {'between', 'values', 'where'}
# g.V().hasLabel('airport').has('lon',between(lon-1,lon+1)).has('lat',between(lat-1,lat+1)).valueMap('code','lat','lon'): {'between', 'valueMap'}
# g.V().has('airport','code','AUS').as('aus').out().has('country',within('US','CA')).where(lt('aus')).by('lon').has('code',without('PHX','LAX')).out().has('code','LAS').path().by('code'): {'where', 'without'}
# g.V().has('code','DFW').values('lon').next(): {'values'}
# g.V().has('airport','code','AUS').as('aus').out().has('country',within('US','CA')).has('lon',lte(dfw)).has('code',without('PHX','LAX')).out().has('code','LAS').path().by('code'): {'without'}
# g.V().has('airport','code','DFW').out().has('country','US').group().by('region').by('code').select('US-CA','US-TX','US-FL','US-CO','US-IL').unfold(): {'unfold', 'group'}
# g.V().hasId(between(1,201)).values('city').order().fold(): {'between', 'values', 'fold'}
# g.V().hasId(between(1,201)).values('city').order().count(): {'between', 'values'}
# g.V().hasId(between(1,201)).values('city').dedup().count(): {'between', 'values'}
# g.addV("A").as("a").addV("B").as("b").addV("C").as("c").addV("D").as("d").addV("E").as("e").addV("F").as("f").addE("knows").from("a").to("b").addE("knows").from("a").to("c").addE("knows").from("a").to("d").addE("knows").from("c").to("d").addE("knows").from("c").to("e").addE("knows").from("d").to("f"): {'addV', 'addE', 'from', 'to'}
# g.V().valueMap(true): {'valueMap'}
# g.addV().property(label,V().has('code','DFW').label()): {'addV'}
# g.V().has('code','DFW').as('dfw').addV().property(label,select('dfw').label()): {'addV'}
# g.V(57525).valueMap(true): {'valueMap'}
# g.V().has('code','DFW').as('dfw').addV().property(label,select('dfw').label()).as('new').property(select('dfw').properties().key(): {'addV', 'key'}
# g.V(53767).valueMap(true).unfold(): {'unfold', 'valueMap'}
# g.V(53767).drop(): {'drop'}
# g.V().has('code','DFW').as('dfw').addV().property(label,select('dfw').label()).as('new').select('dfw').properties().as('dfwprops').select('new').property(select('dfwprops').key(): {'addV', 'key'}
# g.V(53768).valueMap(true).unfold(): {'unfold', 'valueMap'}
# g.V(53768).drop(): {'drop'}
# g.V().has('code','DFW').as('dfw').addV().property(label,select('dfw').label()).as('new').sideEffect(select('dfw').properties().as('dfwprops').select('new').property(select('dfwprops').key(): {'addV', 'key'}
# g.V(53780).valueMap(true).unfold(): {'unfold', 'valueMap'}
# g.addV('root').property('data',9).as('root').addV('node').property('data',5).as('b').addV('node').property('data',2).as('c').addV('node').property('data',11).as('d').addV('node').property('data',15).as('e').addV('node').property('data',10).as('f').addV('node').property('data',1).as('g').addV('node').property('data',8).as('h').addV('node').property('data',22).as('i').addV('node').property('data',16).as('j').addE('left').from('root').to('b').addE('left').from('b').to('c').addE('right').from('root').to('d').addE('right').from('d').to('e').addE('right').from('e').to('i').addE('left').from('i').to('j').addE('left').from('d').to('f').addE('right').from('b').to('h').addE('left').from('c').to('g'): {'addV', 'addE', 'from', 'to'}
# g.V().hasLabel('root').repeat(out('right')).until(out('right').count().is(0)).values('data'): {'values'}
# g.V().hasLabel('root').repeat(out('left')).until(out('left').count().is(0)).values('data'): {'values'}
# g.V().hasLabel('root').repeat(out('left')).until(__.not(out('left'))).values('data'): {'values'}
# g.V().hasLabel('root').repeat(out('left')).emit().values('data'): {'values'}
# g.V().hasLabel('root').repeat(out()).emit().tree().by('data').next(): {'tree'}
# g.V().has('airport','region','GB-ENG').limit(10).map{it.get().value('code'): {'get'}
# g.V().has('code','AUS').repeat(bothE('route').sample(1).by('dist').otherV()).times(5).path().by('code').by('dist'): {'otherV', 'sample'}
# g.V().hasLabel('airport').sample(1).repeat(bothE('route').sample(1).by('dist').otherV()).times(5).path().by('code').by('dist'): {'otherV', 'sample'}
# g.V().hasLabel('airport').repeat(local(bothE('route').sample(1).by('dist').otherV())).times(5).path().by('code').by('dist').limit(5): {'otherV', 'local', 'sample'}
# g.V().has('airport','code',neq('LHR')).filter(out('route').count().is(neq(0))).local(union(identity().values('code'): {'neq', 'values', 'local', 'union'}
# g.V().has('airport','code',neq('AUS')).filter(out('route').count().is(neq(0))).local(repeat(out().simplePath()).emit(has('code','AUS')).times(10).limit(1)).path().by('code').where(count(local).is(gte(8))): {'neq', 'where', 'local'}
# g.V().has('airport','code',neq('AUS')).filter(out('route').count().is(neq(0))).local(repeat(out().simplePath()).until(has('code','AUS').or().loops().is(8)).has('code','AUS').limit(1)).path().by('code').where(count(local).is(gte(8))): {'neq', 'loops', 'where', 'local'}
# g.V().has('code','AUS').repeat(out().where(without('a')).store('a')).times(7).path().by('code'): {'where', 'without', 'store'}
# g.V().has('code','LHR').out().groupCount().by('code').order(local).by(values,desc).next().values().max(): {'values', 'groupCount'}
# g.V().has('code','LHR').out().groupCount().by('code').order(local).by(values,desc): {'groupCount'}
# g.V().as("a").out().as("b").groupCount().by(select("a","b")): {'groupCount'}
# g.V().as("a").out().as("b").groupCount().by(select("a","b")).unfold().filter(select(values).is(gt(1))): {'unfold', 'groupCount'}
# g.V().as("a").out().as("b").groupCount().by(select("a","b")).unfold().filter(select(values).is(gt(1))).select(keys): {'unfold', 'groupCount'}
# g.V().as("a").out().as("b").select('a','b').by('code').groupCount().unfold().filter(select(values).is(gt(1))): {'unfold', 'groupCount'}
# g.V().as("a").out().as("b").select('a','b').by('code').groupCount().unfold().filter(select(values).is(gt(1))).select(keys): {'unfold', 'groupCount'}
# g.V().as("a").out().as("b").select('a','b').by('code').groupCount().unfold().filter(select(values).is(gt(1))).select(keys).select(values): {'unfold', 'groupCount'}
# g.V().has('code','AUS').addE('route').to(V().has('code','CUN')): {'to', 'addE'}
# g.V().has('code','AUS').out().groupCount().by(path().by('code')).limit(local,5): {'groupCount'}
# g.E().hasLabel('route').as('e').values('dist').max().select('e'): {'values'}
# g.E().hasLabel('route').values('dist').max().next(): {'values'}
# g.E().has('dist',r).bothV().values('code'): {'values'}
# g.E().hasLabel('route').as('e').order().by('dist',desc).limit(1).select('e').id().next(): {'id'}
# g.E(r).distg.E(r).bothV().values('code'): {'values'}
# g.E().hasLabel("route").order().by("dist",desc).store("d").by("dist").filter(values("dist").as("cd").select("d").by(limit(local,1)).as("md").where("cd",eq("md"))).project("from","to","dist").by(outV()).by(inV()).by("dist"): {'where', 'values', 'store', 'project', 'eq'}
# g.E().hasLabel("route").order().by("dist",desc).store("d").by("dist"): {'store'}
# g.V().hasLabel('airport').where(out().count().is(gt(500/2))).values('code'): {'values', 'where'}
# g.V().hasLabel('airport').where(out().count().is(gt(a/2))).values('code'): {'values', 'where'}
# g.V().local(out('route').count()).max().next(): {'local'}
# g.V().hasLabel('airport').where(out().count().is(gt(a-50))).project('apt','routes').by('code').by(out().count()): {'project', 'where'}
# 637 queries contain steps not in PyMogwai

# %%
with open("queries.txt", "w") as f:
	counter = 0
	for query, steps in query_step_map.items():
		if len(set(steps)-steps_in_pymogwai)==0:
			counter += 1
			f.write(f"{query}\n")
	print(f"Saved {counter} queries")
# Out:
# Saved 204 queries

# %% [markdown]
# ## Testing wrappers

# %%
from typing import Any, Callable
def parameterizable_step(func:Callable):
    def check_is_hello(x:Any):
        if x == 'hello':
            return True
        elif isinstance(x, (list,tuple)):
            return any(check_is_hello(i for i in x))
        elif isinstance(x, dict):
            return any(check_is_hello(i for i in x.values()))
        return False

    def wrapper(instance, *args, **kwargs):
        if check_is_hello(args) or check_is_hello(kwargs):
            #use a parameter
            return instance._sayhello(*args, **kwargs)
        else: return func(*args, **kwargs)
    return wrapper

class Test:
	@parameterizable_step
	def _sayhello(self, *args, **kwargs):
		print("Hello", args, kwargs)

	def sayhello(self, *args, **kwargs):
		print(args, kwargs)
